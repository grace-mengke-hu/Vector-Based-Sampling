# %%
import sklearn_crfsuite
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite import CRF
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from spacy.lang.en import English
from spacy import displacy
from pathlib import Path
import joblib
from spacy.tokens import Doc
from typing import List
import random
from statistics import mean, stdev
from loguru import logger
import sys
import spacy
from medspacy_io.reader.brat_reader import BratDocReader, BratDirReader
import medspacy

# %% [markdown]
# ## initialize brat reader

# %%
cleaned_train_dir=r'..\data\n2c2\cleaned_training'
cleaned_test_dir=r'..\data\n2c2\cleaned_test'
Path(cleaned_train_dir).exists(), Path(cleaned_test_dir).exists()
# Out:
# (True, True)

# %%
nlp=spacy.load('en_core_web_sm', disable=['ner'])

# %%
dir_reader = BratDirReader(nlp=nlp, schema_file=str(Path(cleaned_train_dir, 'annotation.conf')), support_overlap=True)

# %% [markdown]
# ## Read eHOST annotations | load from pickles

# %%
pickle_file= r'..\data\n2c2\spacy_docs.joblib'

# %%
if not Path(pickle_file).exists():
    train_docs=dir_reader.read(txt_dir=cleaned_train_dir)
    test_docs=dir_reader.read(txt_dir=cleaned_test_dir)
    print(len(train_docs), len(test_docs))
    joblib.dump((train_docs, test_docs), pickle_file)
else:
    print(f'{pickle_file} already exists, load them directly')
    # before load from pickle, initiate EhostDirReader or EhostDocReader first, because some Doc extension used to store meta data will not be automatically recreated by loading.
    train_docs, test_docs=joblib.load(pickle_file)
# Out:
# ..\data\n2c2\spacy_docs.joblib already exists, load them directly

# %% [markdown]
# ## define sampling function

# %%
rounds =10
seed= 14

# %%
len(train_docs), len(test_docs)
# Out:
# (303, 202)

# %% [markdown]
# ## CRF Wrapper (only use for eval)

# %%
from CRFWrapper_Sentence import spans_to_bio, convert_docs, word2features, sent2features,compute_metrics_and_averages,  CRFModel

# %%
## Get all annotation types: 
annos=set()
for d in train_docs:
    for anno in d.spans.keys():
        annos.add(anno)
print(annos)
# Out:
# {'Frequency', 'Duration', 'Form', 'ADE', 'Drug', 'Strength', 'Dosage', 'Route', 'Reason'}

# %%
crf_model=CRFModel(anno_types=annos)

# %% [markdown]
# ## converting docs into sentence level dataframe

# %%
from ALLSampler_Sentence import SamplingSimulator, ModelSamplingSimulator, VBSamplingSimulator, convert_docs_medspacyIOvec

# %%
sdf_labels_train=convert_docs_medspacyIOvec(train_docs)

# %%
_, train_df=convert_docs(train_docs, anno_types=annos)

# %%
_, test_df=convert_docs(test_docs, anno_types=annos)

# %%
pickle_embedding_file= r'..\data\n2c2\embedding_df_uniqueSentID.joblib'#r'..\data\n2c2\embedding_df.joblib'
embedding_df=joblib.load(pickle_embedding_file)

# %%
embedding_df
# Out:
#       sentence_id                                           sentence  \
# 0               0                                  Admission Date:
# 3               1  [**2115-2-22**]              Discharge Date:  ...
# 35              2  [**2078-8-9**]             Sex:   M\n\nService...
# 113             3  [**Known lastname 3234**] is a 36 year old gen...
# 163             4  The patient initially presented to LGH ED with...
# ...           ...                                                ...
# 3059       929923  Cyanocobalamin 1,000 mcg/mL Injection once a m...
# 3071       929924  Lorazepam 0.25 QAM, O.25 QPM, 0.5 mg QHS\n8 Ca...
# 3086       929925                              Cream Topical TID\n9.
# 3092       929926                  Acetaminophen 1000 mg PO Q6H\n10.
# 3100       929927  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
#                                               embedding
# 0     [0.026282, 0.03218903, -0.022386529, 0.0493732...
# 3     [0.016159855, 0.042264156, -0.018290585, -0.05...
# 35    [0.025958579, -0.05749655, 0.012378361, -0.009...
# 113   [0.023170307, 0.03989108, 0.026217388, -0.0272...
# 163   [0.008176211, -0.06342948, 0.048615105, -0.045...
# ...                                                 ...
# 3059  [0.050521564, -0.08905716, -0.0019493615, -0.0...
# 3071  [-0.030010266, -0.062390286, 0.00167252, 0.016...
# 3086  [0.026732022, -0.04987913, 0.024520764, -0.016...
# 3092  [-0.017295217, -0.10513715, -0.0030776137, -0....
# 3100  [0.02337662, 0.021309359, 0.039473698, -0.0429...
#
# [51798 rows x 3 columns]

# %%
sdf_labels_train
# Out:
#                                                 sentence       concept     y  \
# 0      [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1      While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2      While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3      While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4      While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                  ...           ...   ...
# 90405                                   [**Name (NI) **]                 NEG
# 90406                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 90407  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
# 90408                                                 3.                 NEG
# 90409                                                 6.                 NEG
#
#          doc_name
# 0      100035.txt
# 1      100035.txt
# 2      100035.txt
# 3      100035.txt
# 4      100035.txt
# ...           ...
# 90405  198406.txt
# 90406  198406.txt
# 90407  198406.txt
# 90408  198406.txt
# 90409  198406.txt
#
# [90410 rows x 4 columns]

# %%
train_df
# Out:
#       sentence_id    doc_name         token label  \
# 0               0  100035.txt     Admission     O
# 1               0  100035.txt          Date     O
# 2               0  100035.txt             :     O
# 3               1  100035.txt             [     O
# 4               1  100035.txt             *     O
# ...           ...         ...           ...   ...
# 3151       929927  198406.txt      Followup     O
# 3152       929927  198406.txt  Instructions     O
# 3153       929927  198406.txt             :     O
# 3154       929927  198406.txt            \n     O
# 3155       929927  198406.txt      Deceased     O
#
#                                                sentence
# 0                                     Admission Date:
# 1                                     Admission Date:
# 2                                     Admission Date:
# 3     [**2115-2-22**]              Discharge Date:  ...
# 4     [**2115-2-22**]              Discharge Date:  ...
# ...                                                 ...
# 3151  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3152  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3153  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3154  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3155  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
# [932906 rows x 5 columns]

# %%
train_df_embedding = train_df.merge(embedding_df, how='inner', on='sentence_id')

# %%
train_df_embedding
# Out:
#         sentence_id    doc_name         token label  \
# 0                 0  100035.txt     Admission     O
# 1                 0  100035.txt          Date     O
# 2                 0  100035.txt             :     O
# 3                 1  100035.txt             [     O
# 4                 1  100035.txt             *     O
# ...             ...         ...           ...   ...
# 932901       929927  198406.txt      Followup     O
# 932902       929927  198406.txt  Instructions     O
# 932903       929927  198406.txt             :     O
# 932904       929927  198406.txt            \n     O
# 932905       929927  198406.txt      Deceased     O
#
#                                                sentence_x  \
# 0                                       Admission Date:
# 1                                       Admission Date:
# 2                                       Admission Date:
# 3       [**2115-2-22**]              Discharge Date:  ...
# 4       [**2115-2-22**]              Discharge Date:  ...
# ...                                                   ...
# 932901  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932902  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932903  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932904  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932905  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
#                                                sentence_y  \
# 0                                       Admission Date:
# 1                                       Admission Date:
# 2                                       Admission Date:
# 3       [**2115-2-22**]              Discharge Date:  ...
# 4       [**2115-2-22**]              Discharge Date:  ...
# ...                                                   ...
# 932901  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932902  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932903  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932904  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 932905  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
#                                                 embedding
# 0       [0.026282, 0.03218903, -0.022386529, 0.0493732...
# 1       [0.026282, 0.03218903, -0.022386529, 0.0493732...
# 2       [0.026282, 0.03218903, -0.022386529, 0.0493732...
# 3       [0.016159855, 0.042264156, -0.018290585, -0.05...
# 4       [0.016159855, 0.042264156, -0.018290585, -0.05...
# ...                                                   ...
# 932901  [0.02337662, 0.021309359, 0.039473698, -0.0429...
# 932902  [0.02337662, 0.021309359, 0.039473698, -0.0429...
# 932903  [0.02337662, 0.021309359, 0.039473698, -0.0429...
# 932904  [0.02337662, 0.021309359, 0.039473698, -0.0429...
# 932905  [0.02337662, 0.021309359, 0.039473698, -0.0429...
#
# [932906 rows x 7 columns]

# %%
sdf_labels_sid = sdf_labels_train.merge(embedding_df, how='inner', on='sentence')

# %%
sdf_labels_sid
# Out:
#                                                  sentence       concept     y  \
# 0       [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1       While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2       While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3       While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4       While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                   ...           ...   ...
# 638687  Patient had some cardiac enzyme leaks\nduring ...                 NEG
# 638688  Patient was given cardiac healthy diet during ...                 NEG
# 638689  # CODE: DNR/DNI (discussed with patient and so...                 NEG
# 638690                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 638691  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
#
#           doc_name  sentence_id  \
# 0       100035.txt            2
# 1       100035.txt            5
# 2       100035.txt            5
# 3       100035.txt            5
# 4       100035.txt            5
# ...            ...          ...
# 638687  198406.txt       929907
# 638688  198406.txt       929910
# 638689  198406.txt       929911
# 638690  198406.txt       929914
# 638691  198406.txt       929915
#
#                                                 embedding
# 0       [0.025958579, -0.05749655, 0.012378361, -0.009...
# 1       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 2       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 3       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 4       [0.038356796, -0.054362558, 0.028156247, -0.02...
# ...                                                   ...
# 638687  [0.02065785, -0.06587324, 0.055154495, 0.01074...
# 638688  [0.030450102, -0.042418838, 0.00325665, 0.0384...
# 638689  [0.023342747, 0.013347558, -0.01095362, -0.052...
# 638690  [0.02003492, 0.029056935, -0.0140215475, 0.007...
# 638691  [0.013550696, -0.004964338, -0.024216548, -0.0...
#
# [638692 rows x 6 columns]

# %%
train_sentID_list = train_df['sentence_id'].to_list()
train_sentID_set = set(train_sentID_list)
train_sentID_uniqList = list(train_sentID_set)
test_sentID_list = test_df['sentence_id'].to_list()
test_sentID_set = set(test_sentID_list)
test_sentID_uniqList = list(test_sentID_set)

# %%
print(len(train_sentID_uniqList), len(test_sentID_uniqList))
# Out:
# 51798 34334

# %%
int(1.0*len(train_sentID_uniqList)/10)
# Out:
# 5179

# %%
sdf_labels_sid#[['sentence','concept', 'y', 'doc_name_x','sid']]
# Out:
#                                                  sentence       concept     y  \
# 0       [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1       While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2       While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3       While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4       While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                   ...           ...   ...
# 638687  Patient had some cardiac enzyme leaks\nduring ...                 NEG
# 638688  Patient was given cardiac healthy diet during ...                 NEG
# 638689  # CODE: DNR/DNI (discussed with patient and so...                 NEG
# 638690                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 638691  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
#
#           doc_name  sentence_id  \
# 0       100035.txt            2
# 1       100035.txt            5
# 2       100035.txt            5
# 3       100035.txt            5
# 4       100035.txt            5
# ...            ...          ...
# 638687  198406.txt       929907
# 638688  198406.txt       929910
# 638689  198406.txt       929911
# 638690  198406.txt       929914
# 638691  198406.txt       929915
#
#                                                 embedding
# 0       [0.025958579, -0.05749655, 0.012378361, -0.009...
# 1       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 2       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 3       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 4       [0.038356796, -0.054362558, 0.028156247, -0.02...
# ...                                                   ...
# 638687  [0.02065785, -0.06587324, 0.055154495, 0.01074...
# 638688  [0.030450102, -0.042418838, 0.00325665, 0.0384...
# 638689  [0.023342747, 0.013347558, -0.01095362, -0.052...
# 638690  [0.02003492, 0.029056935, -0.0140215475, 0.007...
# 638691  [0.013550696, -0.004964338, -0.024216548, -0.0...
#
# [638692 rows x 6 columns]

# %%
max(sdf_labels_sid['sid'])
# Out:
# 47529

# %%
max(train_df['sentence_id'].to_list())
# Out:
# 929927

# %%
train_df
# Out:
#       sentence_id    doc_name         token label
# 0               0  100035.txt     Admission     O
# 1               0  100035.txt          Date     O
# 2               0  100035.txt             :     O
# 3               1  100035.txt             [     O
# 4               1  100035.txt             *     O
# ...           ...         ...           ...   ...
# 3151       929927  198406.txt      Followup     O
# 3152       929927  198406.txt  Instructions     O
# 3153       929927  198406.txt             :     O
# 3154       929927  198406.txt            \n     O
# 3155       929927  198406.txt      Deceased     O
#
# [932906 rows x 4 columns]

# %%
len(set(train_df['sentence_id'].to_list()))
# Out:
# 51798

# %%
max(train_df['sentence_id'].to_list())
# Out:
# 929927

# %%
#list(set(train_df['sentence_id'].to_list()))

# %%
sdf_labels_train
# Out:
#                                                 sentence       concept     y  \
# 0      [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1      While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2      While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3      While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4      While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                  ...           ...   ...
# 90405                                   [**Name (NI) **]                 NEG
# 90406                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 90407  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
# 90408                                                 3.                 NEG
# 90409                                                 6.                 NEG
#
#          doc_name
# 0      100035.txt
# 1      100035.txt
# 2      100035.txt
# 3      100035.txt
# 4      100035.txt
# ...           ...
# 90405  198406.txt
# 90406  198406.txt
# 90407  198406.txt
# 90408  198406.txt
# 90409  198406.txt
#
# [90410 rows x 4 columns]

# %%
embedding_df
# Out:
#          sid                                           sentence    doc_name  \
# 0          0                                  Admission Date:    100035.txt
# 1          1  [**2115-2-22**]              Discharge Date:  ...  100035.txt
# 2          2  [**2078-8-9**]             Sex:   M\n\nService...  100035.txt
# 3          3  [**Known lastname 3234**] is a 36 year old gen...  100035.txt
# 4          4  The patient initially presented to LGH ED with...  100035.txt
# ...      ...                                                ...         ...
# 47525  47525  Cyanocobalamin 1,000 mcg/mL Injection once a m...  198406.txt
# 47526  47526  Lorazepam 0.25 QAM, O.25 QPM, 0.5 mg QHS\n8 Ca...  198406.txt
# 47527  47527                              Cream Topical TID\n9.  198406.txt
# 47528  47528                  Acetaminophen 1000 mg PO Q6H\n10.  198406.txt
# 47529  47529  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...  198406.txt
#
#                                                embedding
# 0      [0.026282, 0.03218903, -0.022386529, 0.0493732...
# 1      [0.016159855, 0.042264156, -0.018290585, -0.05...
# 2      [0.025958579, -0.05749655, 0.012378361, -0.009...
# 3      [0.023170307, 0.03989108, 0.026217388, -0.0272...
# 4      [0.008176211, -0.06342948, 0.048615105, -0.045...
# ...                                                  ...
# 47525  [0.050521564, -0.08905716, -0.0019493615, -0.0...
# 47526  [-0.030010268, -0.062390275, 0.0016725484, 0.0...
# 47527  [0.026732022, -0.04987913, 0.024520764, -0.016...
# 47528  [-0.017295217, -0.10513715, -0.0030776137, -0....
# 47529  [0.02337662, 0.021309359, 0.039473698, -0.0429...
#
# [47530 rows x 4 columns]

# %% [markdown]
# ## sampling simulator

# %%
faiss_index_path= r'..\data\n2c2\faiss_index_st768'

# %%
pickle_embedding_file= r'..\data\n2c2\embedding_df_uniqueSentID.joblib'# r'..\data\n2c2\embedding_df.joblib'
#sentence	concept	y	doc_name	sentence_id	embedding
embedding_df=joblib.load(pickle_embedding_file)
vb_simulator=VBSamplingSimulator(total_sents=train_df, 
                                 total_round=10, 
                                 modelWrapper=crf_model, 
                                 eval_sents=test_df, 
                                 init_seed=seed, 
                                 faiss_index_path=faiss_index_path, 
                                 embedding_df=embedding_df,
                                 sdf_labels=sdf_labels_sid[['sentence','concept', 'y', 'doc_name','sentence_id']],
                                 min_dist_diff=True
                                )
# Out:
# 2024-05-10 15:17:18.121 | DEBUG    | ALLSampler_Sentence:__init__:221 - Loading index...
# 2024-05-10 15:17:18.938 | DEBUG    | ALLSampler_Sentence:__init__:223 - done

# %% [markdown]
# ## test run

# %%
scores=vb_simulator.simulate_rounds(boostrap_times=3)
# Out:
# 2024-04-26 16:26:50.340 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 0.
# 2024-04-26 16:26:50.342 | DEBUG    | ALLSampler_Sentence:keep_sample:75 - The first round sampling will be random
# 2024-04-26 16:26:50.749 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-04-26 16:26:52.840 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 16:27:54.528 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 16:27:54.620 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 16:28:20.644 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 16:28:24.563 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 16:28:24.707 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9453126300830981, 'recall': 0.7700234244987495, 'f1': 0.8487110171163303}
# 2024-04-26 16:28:24.709 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 1.
# 2024-04-26 16:28:24.710 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 16:28:24.807 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 16:28:25.595 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 16:28:25.595 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 16:28:25.600 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 16:28:25.601 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 16:29:00.330 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 16:29:35.722 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 16:30:10.230 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 16:30:44.687 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 16:31:19.622 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 16:31:54.430 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 16:32:28.651 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 16:33:03.470 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 16:33:38.072 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 16:34:12.677 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 16:34:12.796 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 16:34:13.026 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 16:34:13.179 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5594, remaining sentences: 46204
# 2024-04-26 16:34:15.426 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 16:35:20.805 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 16:35:20.897 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 16:35:47.939 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 16:35:51.857 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 16:35:51.994 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9403861358751014, 'recall': 0.7731767057054758, 'f1': 0.8486209226274398}
# 2024-04-26 16:35:51.996 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 2.
# 2024-04-26 16:35:51.997 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 16:35:52.093 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 16:35:54.830 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 16:35:54.832 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 16:35:54.836 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 16:35:54.837 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 16:36:29.804 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 16:37:04.668 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 16:37:39.728 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 16:38:14.607 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 16:38:49.844 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 16:39:24.420 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 16:39:58.920 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 16:40:33.489 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 16:41:08.069 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 16:41:42.459 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 16:41:42.582 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 16:41:42.806 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 16:41:42.953 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 16:41:45.243 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 16:42:48.891 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 16:42:48.983 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 16:43:15.832 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 16:43:19.899 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 16:43:20.036 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9438035904789882, 'recall': 0.7731513701643499, 'f1': 0.8499920563151065}
# 2024-04-26 16:43:20.038 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 3.
# 2024-04-26 16:43:20.039 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 16:43:20.138 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 16:43:22.961 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 16:43:22.963 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 16:43:22.968 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 16:43:22.969 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 16:43:57.307 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 16:44:31.798 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 16:45:06.102 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 16:45:40.900 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 16:46:15.275 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 16:46:49.485 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 16:47:24.245 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 16:47:58.612 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 16:48:32.833 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 16:49:07.332 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 16:49:07.454 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 16:49:07.621 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 16:49:07.761 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 16:49:09.990 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 16:50:13.905 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 16:50:13.998 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 16:50:39.430 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 16:50:43.392 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 16:50:43.526 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.946511900012423, 'recall': 0.7720254378818693, 'f1': 0.850408110850525}
# 2024-04-26 16:50:43.527 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 4.
# 2024-04-26 16:50:43.529 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 16:50:43.630 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 16:50:46.395 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 16:50:46.396 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 16:50:46.401 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 16:50:46.402 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 16:51:21.628 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 16:51:57.054 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 16:52:32.467 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 16:53:07.346 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 16:53:42.088 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 16:54:16.758 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 16:54:51.698 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 16:55:26.094 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 16:56:01.437 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 16:56:36.423 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 16:56:36.544 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 16:56:36.711 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 16:56:36.847 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 16:56:39.116 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 16:57:42.608 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 16:57:42.676 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 16:58:09.118 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 16:58:13.018 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 16:58:13.144 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9426792604243651, 'recall': 0.7716715977345215, 'f1': 0.8486388706604497}
# 2024-04-26 16:58:13.146 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 5.
# 2024-04-26 16:58:13.147 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 16:58:13.247 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 16:58:16.016 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 16:58:16.018 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 16:58:16.022 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 16:58:16.024 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 16:58:51.442 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 16:59:27.164 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 17:00:03.070 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 17:00:38.532 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 17:01:13.884 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 17:01:49.463 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 17:02:25.233 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 17:03:00.827 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 17:03:35.948 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 17:04:11.586 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 17:04:11.710 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 17:04:11.878 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 17:04:12.016 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 17:04:14.241 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 17:05:18.115 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 17:05:18.181 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 17:05:44.606 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 17:05:48.613 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 17:05:48.744 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9440467161996337, 'recall': 0.7686454001748477, 'f1': 0.8473575908294736}
# 2024-04-26 17:05:48.746 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 6.
# 2024-04-26 17:05:48.747 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 17:05:48.849 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 17:05:51.642 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 17:05:51.643 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 17:05:51.649 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 17:05:51.650 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 17:06:26.838 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 17:07:02.052 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 17:07:37.116 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 17:08:12.234 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 17:08:47.674 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 17:09:23.006 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 17:09:58.689 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 17:10:34.358 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 17:11:09.575 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 17:11:44.521 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 17:11:44.647 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 17:11:44.820 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 17:11:44.963 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 17:11:47.170 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 17:12:50.975 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 17:12:51.042 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 17:13:17.080 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 17:13:21.012 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 17:13:21.147 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9449457063040274, 'recall': 0.773087373618185, 'f1': 0.8504191583437066}
# 2024-04-26 17:13:21.149 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 7.
# 2024-04-26 17:13:21.150 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 17:13:21.252 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 17:13:23.998 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 17:13:24.000 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 17:13:24.004 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 17:13:24.005 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 17:13:59.431 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 17:14:34.785 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 17:15:10.247 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 17:15:45.109 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 17:16:20.713 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 17:16:56.788 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 17:17:32.708 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 17:18:08.676 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 17:18:44.584 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 17:19:20.238 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 17:19:20.363 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 17:19:20.531 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 17:19:20.672 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 17:19:22.977 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 17:20:27.116 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 17:20:27.180 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 17:20:53.646 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 17:20:57.527 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 17:20:57.684 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9451684495697273, 'recall': 0.7710494031843428, 'f1': 0.8492761979799082}
# 2024-04-26 17:20:57.685 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 8.
# 2024-04-26 17:20:57.686 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 17:20:57.785 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 17:21:00.504 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 17:21:00.506 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 17:21:00.511 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 17:21:00.513 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 17:21:35.393 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 17:22:11.111 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 17:22:47.187 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 17:23:22.955 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 17:23:58.593 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 17:24:33.553 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 17:25:09.003 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 17:25:44.912 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 17:26:20.514 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 17:26:56.284 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 17:26:56.407 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 17:26:56.589 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 17:26:56.733 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 17:26:58.941 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 17:28:02.657 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 17:28:02.721 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 17:28:28.832 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 17:28:32.725 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 17:28:32.882 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9449265452648264, 'recall': 0.7725478113866341, 'f1': 0.85008265997899}
# 2024-04-26 17:28:32.884 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 9.
# 2024-04-26 17:28:32.885 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-26 17:28:32.985 | DEBUG    | ALLSampler_Sentence:sample_next_round:325 - Calculating centroids...
# 2024-04-26 17:28:35.680 | DEBUG    | ALLSampler_Sentence:fit:269 - 10 centroids detected from the given sampled_docs
# 2024-04-26 17:28:35.682 | DEBUG    | ALLSampler_Sentence:sample_next_round:328 - Searching from the vector index...
# 2024-04-26 17:28:35.687 | INFO     | ALLSampler_Sentence:sample_next_round:341 - distance shape: (47530, 10), max to retrieve 42352 sentences
# 2024-04-26 17:28:35.688 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: ADE
# 2024-04-26 17:29:11.820 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Dosage
# 2024-04-26 17:29:47.735 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Drug
# 2024-04-26 17:30:23.704 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Duration
# 2024-04-26 17:30:59.724 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Form
# 2024-04-26 17:31:36.004 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Frequency
# 2024-04-26 17:32:12.015 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: NEG
# 2024-04-26 17:32:48.520 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Reason
# 2024-04-26 17:33:24.978 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Route
# 2024-04-26 17:34:00.993 | DEBUG    | ALLSampler_Sentence:sample_next_round:345 - search for centroid: Strength
# 2024-04-26 17:34:36.619 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:287 - Compute min difference between distances to any two centroids.
# 2024-04-26 17:34:36.746 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - Locate the docs of these sentences
# 2024-04-26 17:34:36.917 | DEBUG    | ALLSampler_Sentence:sample_next_round:379 - Update model with new sampled data
# 2024-04-26 17:34:37.055 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5608, remaining sentences: 46190
# 2024-04-26 17:34:37.093 | INFO     | ALLSampler_Sentence:simulate_rounds:97 - It's the last round, now add all docs to sampled.
# 2024-04-26 17:34:58.169 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-26 17:45:11.724 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-26 17:45:12.771 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-26 17:45:38.443 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 3 times
# 2024-04-26 17:45:42.330 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-26 17:45:42.462 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9456164651270845, 'recall': 0.8561456082403112, 'f1': 0.8986573436604449}

# %%
def compute_mean_ci(scores):
    ave=np.mean(scores)
    ci=np.percentile(scores, [2.5, 97.5])
    return ave, ci

summary={'precision': [], 'pl':[], 'pu': [], 'recall': [], 'rl':[], 'ru': [], 'f1':[], 'fl':[], 'fu': []}
for s in scores:    
    for k,v in s.items():
        ave, (l, u)=compute_mean_ci(v)
        summary[k].append(ave)
        summary[k[0]+'l'].append(l)
        summary[k[0]+'u'].append(u)

# %%
pd.options.display.float_format='{:,.5f}'.format
pd.DataFrame(summary)
# Out:
#    precision      pl      pu  recall      rl      ru      f1      fl      fu
# 0    0.94531 0.94270 0.94725 0.77002 0.76820 0.77201 0.84871 0.84658 0.85026
# 1    0.94039 0.93887 0.94243 0.77318 0.76920 0.77592 0.84862 0.84565 0.85037
# 2    0.94380 0.94254 0.94482 0.77315 0.76866 0.77740 0.84999 0.84736 0.85294
# 3    0.94651 0.94501 0.94757 0.77203 0.76746 0.77531 0.85041 0.84704 0.85262
# 4    0.94268 0.94131 0.94346 0.77167 0.76674 0.77575 0.84864 0.84594 0.85055
# 5    0.94405 0.94231 0.94527 0.76865 0.76422 0.77249 0.84736 0.84493 0.84900
# 6    0.94495 0.94232 0.94780 0.77309 0.77217 0.77455 0.85042 0.84887 0.85126
# 7    0.94517 0.94283 0.94774 0.77105 0.76978 0.77258 0.84928 0.84756 0.85124
# 8    0.94493 0.94294 0.94814 0.77255 0.76759 0.77913 0.85008 0.84649 0.85536
# 9    0.94562 0.94501 0.94632 0.85615 0.85242 0.85917 0.89866 0.89635 0.90029

# %% [markdown]
# ## bootstrap 3 runs

# %%
logger.remove()
logger.add(sys.stderr, level='INFO')
# Out:
# 1

# %%
boostrap_runs=3
total_round=10

# %%
random.seed(14)
seeds=[random.randint(1,10000000) for  _ in range(boostrap_runs)]
seeds
# Out:
# [1792286, 8843471, 4142887]

# %%
all_scores=[]
embedding_df=joblib.load(pickle_embedding_file)
for si, seed  in enumerate(seeds):
    logger.info(f'start run {si}.')
    pickle_embedding_file= r'..\data\n2c2\embedding_df_uniqueSentID.joblib' #r'..\data\n2c2\embedding_df.joblib'
    crf_model=CRFModel(anno_types=annos)
    vb_simulator=VBSamplingSimulator(total_sents=train_df, 
                                 total_round=10, 
                                 modelWrapper=crf_model, 
                                 eval_sents=test_df, 
                                 init_seed=seed, 
                                 faiss_index_path=faiss_index_path, 
                                 embedding_df=embedding_df,
                                 sdf_labels=sdf_labels_sid[['sentence','concept', 'y', 'doc_name','sentence_id']],
                                 min_dist_diff=True
                                )
    #v_simulator=VBSamplingSimulator(train_docs, 
    #                                total_round=10, 
    #                                modelWrapper=crf_model, 
    #                                eval_docs=test_docs, 
    #                                init_seed=seed, 
    #                                faiss_index_path=faiss_index_path, 
    #                                embedding_df=embedding_df, 
    #                                min_dist_diff=True)
    scores=vb_simulator.simulate_rounds(boostrap_times=200)
    all_scores.append(scores)
# Out:
# 2024-05-10 15:19:53.534 | INFO     | __main__:<module>:4 - start run 0.
# 2024-05-10 15:19:54.340 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 0.
# 2024-05-10 15:19:54.765 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-05-10 15:25:53.851 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 1.
# 2024-05-10 15:26:35.789 | INFO     | ALLSampler_Sentence:sample_next_round:342 - distance shape: (51798, 10), max to retrieve 46620 sentences
# 2024-05-10 15:32:53.424 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5669, remaining sentences: 46129
# 2024-05-10 15:38:58.234 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 2.
# 2024-05-10 15:39:43.518 | INFO     | ALLSampler_Sentence:sample_next_round:342 - distance shape: (51798, 10), max to retrieve 46620 sentences
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 25
#       7 vb_simulator=VBSamplingSimulator(total_sents=train_df,
#       8                              total_round=10,
#       9                              modelWrapper=crf_model,
#    (...)
#      15                              min_dist_diff=True
#      16                             )
#      17 #v_simulator=VBSamplingSimulator(train_docs,
#      18 #                                total_round=10,
#      19 #                                modelWrapper=crf_model,
#    (...)
#      23 #                                embedding_df=embedding_df,
#      24 #                                min_dist_diff=True)
# ---> 25 scores=vb_simulator.simulate_rounds(boostrap_times=200)
#      26 all_scores.append(scores)
#
# File O:\VINCI_NLPETL\workspace\jianlins\PycharmProjects\vectorsearch\notebooks\ALLSampler_Sentence.py:93, in SamplingSimulator.simulate_rounds(self, boostrap_times)
#      91 for i, r in enumerate(range(self.total_round)):
#      92     logger.info(f'simulate round {i}.')
# ---> 93     self.keep_sample(i==0)
#      94     if i==self.total_round-1:
#      95         self.sampled=self.total_sents
#
# File O:\VINCI_NLPETL\workspace\jianlins\PycharmProjects\vectorsearch\notebooks\ALLSampler_Sentence.py:79, in SamplingSimulator.keep_sample(self, first_round)
#      77 else:
#      78     logger.debug('Sample according to certainties')
# ---> 79     self.sampled, self.remaining = self.sample_next_round(self.sampled, self.remaining, False) #from remaining doc subdataset, sample docs
#      80 num_df_sent_sampled, list_df_UniqSentID_sampled = sent_count(self.sampled)
#      81 num_df_sent_remained, list_df_UniqSentID_remained = sent_count(self.remaining)
#
# File O:\VINCI_NLPETL\workspace\jianlins\PycharmProjects\vectorsearch\notebooks\ALLSampler_Sentence.py:349, in sample_next_round(self, sampled, remaining, randomly)
#     347     new_sampled_sentID.add(sid)
#     348     if len(new_sampled_sentID)>=self.num_per_round:
# --> 349         break;
#     350 new_remaining_sentID = set(remaining['sentence_id'].to_list())-new_sampled_sentID
#     352 #now the sampled data are DF
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\core\generic.py:1927, in NDFrame.__contains__(self, key)
#    1924 @final
#    1925 def __contains__(self, key) -> bool_t:
#    1926     """True if the key is in the info axis"""
# -> 1927     return key in self._info_axis
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\core\indexes\base.py:5146, in Index.__contains__(self, key)
#    5144 hash(key)
#    5145 try:
# -> 5146     return key in self._engine
#    5147 except (OverflowError, TypeError, ValueError):
#    5148     return False
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.__contains__()
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\_libs\index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\_libs\index.pyx:214, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\_libs\index.pyx:222, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File D:\annaconda_env_jianlin\llama2024\lib\site-packages\pandas\_libs\index.pyx:106, in pandas._libs.index._unpack_bool_indexer()
#
# File <__array_function__ internals>:177, in where(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
joblib.dump(all_scores, r'../data/n2c2/scores_sentence_sampling/ner_VBmin_scores_sentenceSampling.joblib')
# Out:
# ['../data/n2c2/scores_sentence_sampling/ner_VBmin_scores_sentenceSampling.joblib']

# %% [markdown]
# ## Debug

# %%
logger.remove()
logger.add(sys.stderr, level='DEBUG')
# Out:
# 2

# %%
#sdf_labels_intSid = sdf_labels_sid({'sid':'int'}) #convert this to int

# %%
pickle_embedding_file= r'..\data\n2c2\embedding_df_uniqueSentID.joblib'
embedding_df=joblib.load(pickle_embedding_file)
vb_simulator=VBSamplingSimulator(total_sents=train_df, 
                                 total_round=10, 
                                 modelWrapper=crf_model, 
                                 eval_sents=test_df, 
                                 init_seed=seed, 
                                 faiss_index_path=faiss_index_path, 
                                 embedding_df=embedding_df,
                                 sdf_labels=sdf_labels_sid[['sentence','concept', 'y', 'doc_name','sentence_id']],
                                 min_dist_diff=True
                                )
# Out:
# 2024-05-10 17:55:35.523 | DEBUG    | ALLSampler_Sentence:__init__:221 - Loading index...
# 2024-05-10 17:55:36.036 | DEBUG    | ALLSampler_Sentence:__init__:223 - done

# %%
vb_simulator.num_per_round=20

# %%
Sampled_1roundRandom,Remaining_1roundRandom=vb_simulator.keep_sample(True)
# Out:
# 2024-05-10 17:57:35.945 | DEBUG    | ALLSampler_Sentence:keep_sample:75 - The first round sampling will be random
# 2024-05-10 17:57:36.375 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 20, remaining sentences: 51778

# %%
def distribution(df):
    gdf=df.groupby('sentence_id')
    nsent={}
    psent={}
    for i,sent in gdf:
        labels=list(sent.label.unique()) #sentence labe is in `concept column`
        labels.remove('O')
        if len(labels)>0:
            psent[i]=(labels, ' '.join([str(t) for t in sent.token]))
        else:
            nsent[i]=(labels,' '.join([str(t) for t in sent.token]))
    return psent, nsent

# %%
psent, nsent=distribution(vb_simulator.sampled)

# %%
len(nsent), len(psent)
# Out:
# (15, 5)

# %%
psent
# Out:
# {16: (['B-Drug'],
#   'Rescucitation last approximately 10 - 15 minutes with multiple \n rounds of epi and bicarb , with ROSC .'),
#  92551: (['B-Drug',
#    'I-Drug',
#    'B-Strength',
#    'I-Strength',
#    'B-Form',
#    'B-Dosage',
#    'I-Dosage',
#    'B-Route',
#    'B-Frequency',
#    'I-Frequency'],
#   'Refills:*2 * \n 2 . ranitidine HCl 300 mg Tablet Sig : One ( 1 ) Tablet PO at \n bedtime .'),
#  425908: (['B-Reason', 'I-Reason', 'B-Drug'],
#   'Brief Hospital Course : \n 79F with locally advanced pancreatic CA on Xeloda and \n oxaliplatin ( C2D1'),
#  471728: (['B-Drug',
#    'B-Strength',
#    'I-Strength',
#    'B-Form',
#    'B-Dosage',
#    'I-Dosage',
#    'B-Route',
#    'B-Frequency',
#    'I-Frequency'],
#   'Captopril 25 mg Tablet Sig : One ( 1 ) Tablet PO BID ( 2 times a \n day ) .'),
#  619225: (['B-Drug',
#    'B-Strength',
#    'I-Strength',
#    'B-Form',
#    'I-Form',
#    'B-Dosage',
#    'I-Dosage',
#    'B-Route',
#    'B-Frequency',
#    'I-Frequency'],
#   'verapamil 120 mg Tablet Extended Release Sig : One ( 1 ) Tablet \n Extended Release PO Q24H ( every 24 hours ) .')}

# %%
vb_simulator.sampled
# Out:
#      sentence_id    doc_name          token label  \
# 0             16  100035.txt  Rescucitation     O
# 1             16  100035.txt           last     O
# 2             16  100035.txt  approximately     O
# 3             16  100035.txt             10     O
# 4             16  100035.txt              -     O
# ..           ...         ...            ...   ...
# 444       859499  182160.txt            the     O
# 445       859499  182160.txt          first     O
# 446       859499  182160.txt          month     O
# 447       859499  182160.txt  postoperative     O
# 448       859499  182160.txt              .     O
#
#                                               sentence
# 0    Rescucitation last approximately 10-15 minutes...
# 1    Rescucitation last approximately 10-15 minutes...
# 2    Rescucitation last approximately 10-15 minutes...
# 3    Rescucitation last approximately 10-15 minutes...
# 4    Rescucitation last approximately 10-15 minutes...
# ..                                                 ...
# 444  Fatigue is\nnormal, especially for the first m...
# 445  Fatigue is\nnormal, especially for the first m...
# 446  Fatigue is\nnormal, especially for the first m...
# 447  Fatigue is\nnormal, especially for the first m...
# 448  Fatigue is\nnormal, especially for the first m...
#
# [449 rows x 5 columns]

# %%
sampled_sendIDlist = set(vb_simulator.sampled['sentence_id'])
logger.debug(f'sampled_sendIDlist: {len(sampled_sendIDlist)}')
sampled_sdf = vb_simulator.sdf_labels[vb_simulator.sdf_labels['sentence_id'].isin(sampled_sendIDlist)]
# Out:
# 2024-05-10 18:20:36.957 | DEBUG    | __main__:<module>:2 - sampled_sendIDlist: 20

# %%
type(list(sampled_sendIDlist)[0])
# Out:
# int

# %%
type(vb_simulator.sdf_labels.iloc[0].sentence_id) # type in consistent: Int is not instance of numpy.int64
# Out:
# numpy.int32

# %%
vb_simulator.sdf_labels
# Out:
#                                                  sentence       concept     y  \
# 0       [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1       While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2       While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3       While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4       While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                   ...           ...   ...
# 638687  Patient had some cardiac enzyme leaks\nduring ...                 NEG
# 638688  Patient was given cardiac healthy diet during ...                 NEG
# 638689  # CODE: DNR/DNI (discussed with patient and so...                 NEG
# 638690                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 638691  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
#
#           doc_name  sentence_id
# 0       100035.txt            2
# 1       100035.txt            5
# 2       100035.txt            5
# 3       100035.txt            5
# 4       100035.txt            5
# ...            ...          ...
# 638687  198406.txt       929907
# 638688  198406.txt       929910
# 638689  198406.txt       929911
# 638690  198406.txt       929914
# 638691  198406.txt       929915
#
# [638692 rows x 5 columns]

# %%
sdf_labels_intSid = vb_simulator.sdf_labels.astype({'sentence_id':'int'})

# %%
type(sdf_labels_intSid.iloc[0].sentence_id) #int32 is type of int
# Out:
# numpy.int32

# %%
sampled_sendIDlist = set(vb_simulator.sampled['sentence_id'])
logger.debug(f'sampled_sendIDlist: {len(sampled_sendIDlist)}')
sampled_sdf_intSid = sdf_labels_intSid[sdf_labels_intSid['sentence_id'].isin(sampled_sendIDlist)]
# Out:
# 2024-05-10 18:21:04.536 | DEBUG    | __main__:<module>:2 - sampled_sendIDlist: 20

# %%
sampled_sendIDlist = set(vb_simulator.sampled['sentence_id'])

# %%
sampled_sendIDlist
# Out:
# {16,
#  15910,
#  92551,
#  278115,
#  278202,
#  281654,
#  362102,
#  425908,
#  471728,
#  591966,
#  619225,
#  644536,
#  647271,
#  662894,
#  662924,
#  679460,
#  691088,
#  735111,
#  761429,
#  859499}

# %%
vb_simulator.sampled
# Out:
#      sentence_id    doc_name          token label  \
# 0             16  100035.txt  Rescucitation     O
# 1             16  100035.txt           last     O
# 2             16  100035.txt  approximately     O
# 3             16  100035.txt             10     O
# 4             16  100035.txt              -     O
# ..           ...         ...            ...   ...
# 444       859499  182160.txt            the     O
# 445       859499  182160.txt          first     O
# 446       859499  182160.txt          month     O
# 447       859499  182160.txt  postoperative     O
# 448       859499  182160.txt              .     O
#
#                                               sentence
# 0    Rescucitation last approximately 10-15 minutes...
# 1    Rescucitation last approximately 10-15 minutes...
# 2    Rescucitation last approximately 10-15 minutes...
# 3    Rescucitation last approximately 10-15 minutes...
# 4    Rescucitation last approximately 10-15 minutes...
# ..                                                 ...
# 444  Fatigue is\nnormal, especially for the first m...
# 445  Fatigue is\nnormal, especially for the first m...
# 446  Fatigue is\nnormal, especially for the first m...
# 447  Fatigue is\nnormal, especially for the first m...
# 448  Fatigue is\nnormal, especially for the first m...
#
# [449 rows x 5 columns]

# %% [markdown]
# ### next round

# %%
vb_simulator.modelWrapper.fit(vb_simulator.sampled)
# Out:
# 2024-05-10 18:24:37.167 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-10 18:24:37.384 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.

# %%
vb_simulator.fit(vb_simulator.sampled)
# Out:
# 2024-05-10 18:24:50.023 | DEBUG    | ALLSampler_Sentence:fit:270 - 8 centroids detected from the given sampled_docs

# %%
vb_simulator.remaining.shape
# Out:
# (932457, 5)

# %%
psent
# Out:
# {16: (['B-Drug'],
#   'Rescucitation last approximately 10 - 15 minutes with multiple \n rounds of epi and bicarb , with ROSC .'),
#  92551: (['B-Drug',
#    'I-Drug',
#    'B-Strength',
#    'I-Strength',
#    'B-Form',
#    'B-Dosage',
#    'I-Dosage',
#    'B-Route',
#    'B-Frequency',
#    'I-Frequency'],
#   'Refills:*2 * \n 2 . ranitidine HCl 300 mg Tablet Sig : One ( 1 ) Tablet PO at \n bedtime .'),
#  425908: (['B-Reason', 'I-Reason', 'B-Drug'],
#   'Brief Hospital Course : \n 79F with locally advanced pancreatic CA on Xeloda and \n oxaliplatin ( C2D1'),
#  471728: (['B-Drug',
#    'B-Strength',
#    'I-Strength',
#    'B-Form',
#    'B-Dosage',
#    'I-Dosage',
#    'B-Route',
#    'B-Frequency',
#    'I-Frequency'],
#   'Captopril 25 mg Tablet Sig : One ( 1 ) Tablet PO BID ( 2 times a \n day ) .'),
#  619225: (['B-Drug',
#    'B-Strength',
#    'I-Strength',
#    'B-Form',
#    'I-Form',
#    'B-Dosage',
#    'I-Dosage',
#    'B-Route',
#    'B-Frequency',
#    'I-Frequency'],
#   'verapamil 120 mg Tablet Extended Release Sig : One ( 1 ) Tablet \n Extended Release PO Q24H ( every 24 hours ) .')}

# %%
sampled=vb_simulator.sampled

# %%
gsampled=sampled.groupby('sentence_id')

# %%
len(gsampled)
# Out:
# 20

# %%
vb_simulator.sdf_labels[vb_simulator.sdf_labels.sentence_id==611466]
# Out:
#                                                  sentence  \
# 610685  Transthoracic echo\nrevealed diastolic heart f...
# 610686  Transthoracic echo\nrevealed diastolic heart f...
# 610687  Transthoracic echo\nrevealed diastolic heart f...
#
#                         concept       y    doc_name  sentence_id
# 610685  diastolic heart failure  Reason  118418.txt       611466
# 610686                enalapril    Drug  118418.txt       611466
# 610687                    Lasix    Drug  118418.txt       611466

# %%
len(set(sampled_sendIDlist))
# Out:
# 20

# %%
vb_simulator.sample_next_round(vb_simulator.sampled, vb_simulator.remaining, randomly=False)
# Out:
# 2024-05-10 18:29:44.568 | DEBUG    | ALLSampler_Sentence:sample_next_round:326 - Calculating centroids...
# 2024-05-10 18:29:45.112 | DEBUG    | ALLSampler_Sentence:fit:270 - 8 centroids detected from the given sampled_docs
# 2024-05-10 18:29:45.114 | DEBUG    | ALLSampler_Sentence:sample_next_round:329 - Searching from the vector index...
# 2024-05-10 18:29:45.119 | INFO     | ALLSampler_Sentence:sample_next_round:342 - distance shape: (51798, 8), max to retrieve 46620 sentences
# 2024-05-10 18:29:45.120 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Dosage
# 2024-05-10 18:30:24.696 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Drug
# 2024-05-10 18:31:04.071 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Form
# 2024-05-10 18:31:43.507 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Frequency
# 2024-05-10 18:32:23.293 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: NEG
# 2024-05-10 18:33:02.425 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Reason
# 2024-05-10 18:33:40.873 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Route
# 2024-05-10 18:34:20.275 | DEBUG    | ALLSampler_Sentence:sample_next_round:346 - search for centroid: Strength
# 2024-05-10 18:34:59.874 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:288 - Compute min difference between distances to any two centroids.
# 2024-05-10 18:34:59.955 | DEBUG    | ALLSampler_Sentence:sample_next_round:357 - Locate the docs of these sentences
# 2024-05-10 18:35:00.244 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - Update model with new sampled data
# (     sentence_id    doc_name          token label  \
#  0             16  100035.txt  Rescucitation     O
#  1             16  100035.txt           last     O
#  2             16  100035.txt  approximately     O
#  3             16  100035.txt             10     O
#  4             16  100035.txt              -     O
#  ..           ...         ...            ...   ...
#  936           23  100035.txt           Poor     O
#  937           23  100035.txt            air     O
#  938           23  100035.txt       movement     O
#  939           23  100035.txt    bilaterally     O
#  940           23  100035.txt              .     O
#
#                                                sentence
#  0    Rescucitation last approximately 10-15 minutes...
#  1    Rescucitation last approximately 10-15 minutes...
#  2    Rescucitation last approximately 10-15 minutes...
#  3    Rescucitation last approximately 10-15 minutes...
#  4    Rescucitation last approximately 10-15 minutes...
#  ..                                                 ...
#  936  CV: Tachy S1+S2\nPulm: Poor air movement bilat...
#  937  CV: Tachy S1+S2\nPulm: Poor air movement bilat...
#  938  CV: Tachy S1+S2\nPulm: Poor air movement bilat...
#  939  CV: Tachy S1+S2\nPulm: Poor air movement bilat...
#  940  CV: Tachy S1+S2\nPulm: Poor air movement bilat...
#
#  [941 rows x 5 columns],
#        sentence_id    doc_name         token label  \
#  392            14  100035.txt            He     O
#  393            14  100035.txt           had     O
#  394            14  100035.txt             a     O
#  395            14  100035.txt           CTH     O
#  396            14  100035.txt         which     O
#  ...           ...         ...           ...   ...
#  3151       929927  198406.txt      Followup     O
#  3152       929927  198406.txt  Instructions     O
#  3153       929927  198406.txt             :     O
#  3154       929927  198406.txt            \n     O
#  3155       929927  198406.txt      Deceased     O
#
#                                                 sentence
#  392                He had a CTH which was unremarkable.
#  393                He had a CTH which was unremarkable.
#  394                He had a CTH which was unremarkable.
#  395                He had a CTH which was unremarkable.
#  396                He had a CTH which was unremarkable.
#  ...                                                 ...
#  3151  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#  3152  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#  3153  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#  3154  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#  3155  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
#  [931965 rows x 5 columns])

# %%
vb_simulator.sampled
# Out:
#      sentence_id    doc_name          token label  \
# 0             16  100035.txt  Rescucitation     O
# 1             16  100035.txt           last     O
# 2             16  100035.txt  approximately     O
# 3             16  100035.txt             10     O
# 4             16  100035.txt              -     O
# ..           ...         ...            ...   ...
# 444       859499  182160.txt            the     O
# 445       859499  182160.txt          first     O
# 446       859499  182160.txt          month     O
# 447       859499  182160.txt  postoperative     O
# 448       859499  182160.txt              .     O
#
#                                               sentence
# 0    Rescucitation last approximately 10-15 minutes...
# 1    Rescucitation last approximately 10-15 minutes...
# 2    Rescucitation last approximately 10-15 minutes...
# 3    Rescucitation last approximately 10-15 minutes...
# 4    Rescucitation last approximately 10-15 minutes...
# ..                                                 ...
# 444  Fatigue is\nnormal, especially for the first m...
# 445  Fatigue is\nnormal, especially for the first m...
# 446  Fatigue is\nnormal, especially for the first m...
# 447  Fatigue is\nnormal, especially for the first m...
# 448  Fatigue is\nnormal, especially for the first m...
#
# [449 rows x 5 columns]

# %%
len(set(vb_simulator.sampled.sentence_id.to_list())) #20
len(set(vb_simulator.remaining.sentence_id.to_list())) #51778
# Out:
# 51778

# %%
vb_simulator.remaining
# Out:
#       sentence_id    doc_name         token label  \
# 0               0  100035.txt     Admission     O
# 1               0  100035.txt          Date     O
# 2               0  100035.txt             :     O
# 3               1  100035.txt             [     O
# 4               1  100035.txt             *     O
# ...           ...         ...           ...   ...
# 3151       929927  198406.txt      Followup     O
# 3152       929927  198406.txt  Instructions     O
# 3153       929927  198406.txt             :     O
# 3154       929927  198406.txt            \n     O
# 3155       929927  198406.txt      Deceased     O
#
#                                                sentence
# 0                                     Admission Date:
# 1                                     Admission Date:
# 2                                     Admission Date:
# 3     [**2115-2-22**]              Discharge Date:  ...
# 4     [**2115-2-22**]              Discharge Date:  ...
# ...                                                 ...
# 3151  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3152  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3153  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3154  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3155  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
# [932457 rows x 5 columns]

# %% [markdown]
# ## Isssue

# %%
sampled_sdf = vb_simulator.sdf_labels[vb_simulator.sdf_labels['sentence_id'].isin(list(set(sampled_sendIDlist)))]

# %%
vb_simulator.sdf_labels
# Out:
#                                                  sentence       concept     y  \
# 0       [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1       While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2       While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3       While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4       While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                   ...           ...   ...
# 638687  Patient had some cardiac enzyme leaks\nduring ...                 NEG
# 638688  Patient was given cardiac healthy diet during ...                 NEG
# 638689  # CODE: DNR/DNI (discussed with patient and so...                 NEG
# 638690                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 638691  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
#
#           doc_name  sentence_id
# 0       100035.txt            2
# 1       100035.txt            5
# 2       100035.txt            5
# 3       100035.txt            5
# 4       100035.txt            5
# ...            ...          ...
# 638687  198406.txt       929907
# 638688  198406.txt       929910
# 638689  198406.txt       929911
# 638690  198406.txt       929914
# 638691  198406.txt       929915
#
# [638692 rows x 5 columns]

# %%
sampled_sdf
# Out:
#                                                  sentence  \
# 81840                                                  2.
# 82129                                                  2.
# 82418                                                  2.
# 82707                                                  2.
# 82996                                                  2.
# ...                                                   ...
# 610685  Transthoracic echo\nrevealed diastolic heart f...
# 610686  Transthoracic echo\nrevealed diastolic heart f...
# 610687  Transthoracic echo\nrevealed diastolic heart f...
# 621891  Denies\nparoxysmal nocturnal dyspnea, orthopne...
# 630039  He had a\nbowel movement on postoperative day ...
#
#                         concept       y    doc_name  sentence_id
# 81840                               NEG  100035.txt       637949
# 82129                               NEG  100039.txt       637949
# 82418                               NEG  100039.txt       637949
# 82707                               NEG  100039.txt       637949
# 82996                               NEG  100187.txt       637949
# ...                         ...     ...         ...          ...
# 610685  diastolic heart failure  Reason  118418.txt       611466
# 610686                enalapril    Drug  118418.txt       611466
# 610687                    Lasix    Drug  118418.txt       611466
# 621891                              NEG  143451.txt       731921
# 630039                              NEG  172474.txt       827217
#
# [446 rows x 5 columns]

# %%
sampled_sendIDlist
# Out:
# {143370,
#  173777,
#  177318,
#  179101,
#  238893,
#  241062,
#  247359,
#  335612,
#  383947,
#  384017,
#  457226,
#  541227,
#  541265,
#  545918,
#  588558,
#  606928,
#  611466,
#  637949,
#  731921,
#  827217}

# %%
#sampled_sendIDlist

# %%
vb_simulator.centroid.keys()
# Out:
# dict_keys(['Drug', 'Form', 'NEG', 'Reason'])

# %%
set(sampled_sdf.y.to_list())
# Out:
# {'Drug', 'Form', 'NEG', 'Reason'}
