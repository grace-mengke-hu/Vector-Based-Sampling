# %%
import sklearn_crfsuite
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite import CRF
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from spacy.lang.en import English
from spacy import displacy
from pathlib import Path
import joblib
from spacy.tokens import Doc
from typing import List
import random
from statistics import mean, stdev
from loguru import logger
import sys
import spacy
from medspacy_io.reader.brat_reader import BratDocReader, BratDirReader
import medspacy

# %% [markdown]
# ## Initiate Brat Reader

# %%
cleaned_train_dir=r'..\data\n2c2\cleaned_training'
cleaned_test_dir=r'..\data\n2c2\cleaned_test'
Path(cleaned_train_dir).exists(), Path(cleaned_test_dir).exists()
# Out:
# (True, True)

# %%
nlp=spacy.load('en_core_web_sm', disable=['ner'])

# %%
dir_reader = BratDirReader(nlp=nlp, schema_file=str(Path(cleaned_train_dir, 'annotation.conf')), support_overlap=True)

# %% [markdown]
# ## Read Brat annotations | load from pickles

# %%
pickle_file= r'..\data\n2c2\spacy_docs.joblib'

# %%
if not Path(pickle_file).exists():
    train_docs=dir_reader.read(txt_dir=cleaned_train_dir)
    test_docs=dir_reader.read(txt_dir=cleaned_test_dir)
    print(len(train_docs), len(test_docs))
    joblib.dump((train_docs, test_docs), pickle_file)
else:
    print(f'{pickle_file} already exists, load them directly')
    # before load from pickle, initiate EhostDirReader or EhostDocReader first, because some Doc extension used to store meta data will not be automatically recreated by loading.
    train_docs, test_docs=joblib.load(pickle_file)
# Out:
# ..\data\n2c2\spacy_docs.joblib already exists, load them directly

# %% [markdown]
# ## Define sampling function

# %%
rounds =10
seed= 14

# %%
len(train_docs), len(test_docs)
# Out:
# (303, 202)

# %% [markdown]
# ## CRF Wrapper

# %%
from CRFWrapper_Sentence import spans_to_bio, convert_docs, word2features, sent2features,compute_metrics_and_averages,  CRFModel

# %%
## Get all annotation types: 
annos=set()
for d in train_docs:
    for anno in d.spans.keys():
        annos.add(anno)
print(annos)
# Out:
# {'Strength', 'Duration', 'Route', 'Frequency', 'Drug', 'Dosage', 'Reason', 'Form', 'ADE'}

# %%
crf_model=CRFModel(anno_types=annos)

# %% [markdown]
# ## Convert training and testing docs into sentence level dataframe

# %%
_, train_df=convert_docs(train_docs, anno_types=annos)

# %%
_, test_df=convert_docs(test_docs, anno_types=annos)

# %%
train_df
# Out:
#       sentence_id    doc_name         token label
# 0               0  100035.txt     Admission     O
# 1               0  100035.txt          Date     O
# 2               0  100035.txt             :     O
# 3               1  100035.txt             [     O
# 4               1  100035.txt             *     O
# ...           ...         ...           ...   ...
# 3151       929927  198406.txt      Followup     O
# 3152       929927  198406.txt  Instructions     O
# 3153       929927  198406.txt             :     O
# 3154       929927  198406.txt            \n     O
# 3155       929927  198406.txt      Deceased     O
#
# [932906 rows x 4 columns]

# %%
train_df.label.unique()
# Out:
# array(['O', 'B-Drug', 'B-Route', 'B-Reason', 'I-Reason', 'B-Strength',
#        'I-Strength', 'B-Frequency', 'B-Duration', 'I-Duration', 'B-Form',
#        'B-Dosage', 'I-Dosage', 'B-ADE', 'I-Frequency', 'I-Drug', 'I-Form',
#        'I-Route', 'I-ADE'], dtype=object)

# %%
gdf=train_df.groupby('sentence_id')

# %%
nsent=[]
psent=[]
for i,sent in gdf:
    if len(sent.label.unique())>1:
        psent.append(sent)
    else:
        nsent.append(sent)

# %%
from spacy import displacy
from spacy.tokens import Span

# %%
text='welcome to the bank of china.'
doc=nlp(text)
doc.spans['mk']=[Span(doc, 3,6, 'ORG'), Span(doc, 5,6, "GPE")]

# %%
displacy.render(doc,style='span')
# Out:
# <span class="tex2jax_ignore"><div class="spans" style="line-height: 2.5; direction: ltr">Admission Date :   [ * * 2115 - 2 - 22 * * ]               Discharge Date :    [ * * 2115 - 3 - 19 * * ]
#
#  Date of Birth :   [ * * 2078 - 8 - 9 * * ]              Sex :    M
#
#  Service : MEDICINE
#
#  Allergies :
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     Vicodin
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
#
#
#  Attending:[**First Name3 ( LF ) 4891 * * ]
#  Chief Complaint :
#  Post - cardiac arrest , asthma exacerbation
#
#  Major Surgical or Invasive Procedure :
#  Intubation
#  Removal of chest tubes placed at an outside hospital
#  R CVL placement
#
#
#  History of Present Illness :
#  Mr. [ * * Known lastname 3234 * * ] is a 36 year old gentleman with a PMH signifciant
#  with dilated cardiomyopathy s / p AICD , asthma , and HTN admitted
#  to an OSH with dyspnea now admitted to the MICU after PEA arrest
#  x2 . The patient initially presented to LGH ED with hypoxemic
#  respiratory distress . While at the OSH , he received
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     CTX
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# ,
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     azithromycin
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# ,
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     SC
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Route
#     </span>
# </span>
#
#
# </span>
#
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     epinephrine
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# , and
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     solumedrol
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# . While at the OSH ,
#  he became confused and subsequently had an episode of PEA arrest
#  and was intubated . He received
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     epinephrine
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# ,
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     atropine
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# ,
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     magnesium
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# ,
#  and
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     bicarb
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top: 40px; height: 4px; border-top-left-radius: 3px; border-bottom-left-radius: 3px; left: -1px; width: calc(100% + 2px); position: absolute;">
#     <span style="background: #ddd; z-index: 10; color: #000; top: -0.5em; padding: 2px 3px; position: absolute; font-size: 0.6em; font-weight: bold; line-height: 1; border-radius: 3px">
#         Drug
#     </span>
# </span>
#
#
# </span>
# . In addition , he had bilateral needle thoracostomies
#  with report of air return on the left , and he subsequently had
#  bilateral chest tubes placed .   After approximately 15 - 20 minutes
#  of rescucitation , he had ROSC . He received
# <span style="font-weight: bold; display: inline-block; position: relative; height: 60px;">
#     vecuronium
#
# <span style="background: #ddd; top: 40px; height: 4px; left: -1px; width: calc(100% + 2px); position: absolute;">
# </span>
#
#
# <span style="background: #ddd; top:

# %%
doc=train_docs[0]

# %%
sps=[s for sps in doc.spans.values() for s in sps]

# %%
doc.spans['sc']=sps

# %%
len(list(train_docs[1].sents))
# Out:
# 372

# %%
span=train_docs[1].spans['Drug'][0]

# %%
sents=list(train_docs[1].sents)

# %%
slens={len(s):s for s in sents}

# %%
sls=sorted(slens.keys())

# %%
slens[sls[-3]]
# Out:
# [**2173-1-11**], course
# complicated by neutropenic fever and acute skin GVHD
#
# OTHER MEDICAL HISTORY:
# - Embolic stroke in [**3-/2174**] on coumadin
# - Cardiomyopathy due to early anthracycline-related
# cardiotoxicity [**10/2172**]
# - Chronic kidney disease stage III/IV, baseline creatinine
# ~2.0-2.2
# - Asthma
# - HTN
# - Cervical Intraepithelial neoplasia
# - C-section in [**2165**]
#
#
# Social History:
# Smoke: never
# EtOH:

# %%
displacy.render(train_docs[1], style='span')

# %%
visualize_ent(train_docs[0], target_span_type='group', span_group_name='B-Drug')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 visualize_ent(train_docs[0], target_span_type='group', span_group_name='B-Drug')
#
# TypeError: visualize_ent() got an unexpected keyword argument 'target_span_type'

# %%
visualize_ent
# Out:
# 12029

# %%
len(nsent)
# Out:
# 39769

# %%
train_sentID_list = train_df['sentence_id'].to_list()
train_sentID_set = set(train_sentID_list)
train_sentID_uniqList = list(train_sentID_set)
test_sentID_list = test_df['sentence_id'].to_list()
test_sentID_set = set(test_sentID_list)
test_sentID_uniqList = list(test_sentID_set)

# %%
print(len(train_sentID_uniqList), len(test_sentID_uniqList))
# Out:
# 51798 34334

# %%
int(1.0*len(train_sentID_uniqList)/10)
# Out:
# 5179

# %% [markdown]
# ## sampling simulator

# %%
from ALLSampler_Sentence import SamplingSimulator, ModelSamplingSimulator

# %%
m_simulator=ModelSamplingSimulator(total_sents=train_df, 
                                   total_round=10, 
                                   modelWrapper=crf_model, 
                                   eval_sents=test_df, 
                                   init_seed=seed)

# %%
train_df.columns
# Out:
# Index(['sentence_id', 'doc_name', 'token', 'label'], dtype='object')

# %%
sampled, remaining=m_simulator.sample_next_round(pd.DataFrame({k:[] for k in train_df.columns}), train_df)

# %%
gdf=sampled.groupby('sentence_id')

# %%
nsent=[]
psent=[]
for i,sent in gdf:
    if len(sent.label.unique())>1:
        psent.append(sent)
    else:
        nsent.append(sent)

# %%
len(psent), len(nsent)
# Out:
# (1153, 4026)

# %%
m_simulator.modelWrapper.fit(sampled)
# Out:
# 2024-05-01 13:39:27.654 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-05-01 13:40:27.417 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.

# %%
round_scores=m_simulator.modelWrapper.bootstrap_eval_DFsent(m_simulator.eval_sents, 1)
# Out:
# 2024-05-01 13:40:27.521 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-05-01 13:40:52.404 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 1 times
# 2024-05-01 13:40:53.648 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete

# %%
round_scores
# Out:
# {'precision': [0.9461084511747021],
#  'recall': [0.77212697643424],
#  'f1': [0.8503093883950165]}

# %%
sampled, remaining=m_simulator.sample_next_round(sampled, remaining, randomly=False)
# Out:
# 2024-05-01 13:50:24.462 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 5179 sentences samples
# 2024-05-01 13:50:24.463 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-05-01 13:51:25.184 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 839161 rows, sort indx on certainty for 46619 sentences
# 2024-05-01 13:51:25.331 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data

# %%
gdf=sampled.groupby('sentence_id')
nsent=[]
psent=[]
for i,sent in gdf:
    if len(sent.label.unique())>1:
        psent.append(sent)
    else:
        nsent.append(sent)
len(psent), len(nsent)
# Out:
# (2367, 7991)

# %%
m_simulator.modelWrapper.fit(sampled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 m_simulator.modelWrapper.fit(sampled)
#
# NameError: name 'm_simulator' is not defined

# %%
round_scores=m_simulator.modelWrapper.bootstrap_eval_DFsent(m_simulator.eval_sents, 1)
round_scores

# %% [markdown]
# ## test run

# %%
scores=m_simulator.simulate_rounds() #sample sentences for 10 rounds; each round bootstrap sampling 200 for evaluation
# Out:
# 2024-04-23 23:49:06.744 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 0.
# 2024-04-23 23:49:06.746 | DEBUG    | ALLSampler_Sentence:keep_sample:75 - The first round sampling will be random
# 2024-04-23 23:49:07.146 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-04-23 23:49:09.124 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-23 23:50:07.596 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-23 23:50:07.690 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-23 23:50:32.987 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-23 23:54:44.927 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-23 23:54:45.055 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9460863337731906, 'recall': 0.7718258294774815, 'f1': 0.8501139611079124}
# 2024-04-23 23:54:45.057 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 1.
# 2024-04-23 23:54:45.059 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-23 23:54:45.157 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 5179 sentences samples
# 2024-04-23 23:54:45.159 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-23 23:55:43.954 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 839161 rows, sort indx on certainty for 46619 sentences
# 2024-04-23 23:55:44.107 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-23 23:55:44.242 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 10358, remaining sentences: 41440
# 2024-04-23 23:55:48.196 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-23 23:57:43.353 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-23 23:57:43.524 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-23 23:58:07.964 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 00:02:20.937 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 00:02:21.061 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.941900437966913, 'recall': 0.8131657689266593, 'f1': 0.8728080310655052}
# 2024-04-24 00:02:21.063 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 2.
# 2024-04-24 00:02:21.064 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 00:02:21.165 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 10358 sentences samples
# 2024-04-24 00:02:21.167 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 00:03:13.800 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 745556 rows, sort indx on certainty for 41440 sentences
# 2024-04-24 00:03:13.934 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 00:03:14.060 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 15537, remaining sentences: 36261
# 2024-04-24 00:03:20.509 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 00:06:16.762 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 00:06:17.026 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 00:06:41.727 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 00:10:53.698 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 00:10:53.827 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9429590162111353, 'recall': 0.8263665829508511, 'f1': 0.8808181995838789}
# 2024-04-24 00:10:53.829 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 3.
# 2024-04-24 00:10:53.830 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 00:10:53.932 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 15537 sentences samples
# 2024-04-24 00:10:53.934 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 00:11:40.043 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 651983 rows, sort indx on certainty for 36261 sentences
# 2024-04-24 00:11:40.172 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 00:11:40.310 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 20716, remaining sentences: 31082
# 2024-04-24 00:11:48.050 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 00:15:51.721 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 00:15:52.116 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 00:16:17.614 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 00:20:30.396 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 00:20:30.508 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9446342276592472, 'recall': 0.8359365365026359, 'f1': 0.8869650335146727}
# 2024-04-24 00:20:30.511 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 4.
# 2024-04-24 00:20:30.512 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 00:20:30.608 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 20716 sentences samples
# 2024-04-24 00:20:30.611 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 00:21:09.432 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 557807 rows, sort indx on certainty for 31082 sentences
# 2024-04-24 00:21:09.548 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 00:21:09.680 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 25895, remaining sentences: 25903
# 2024-04-24 00:21:20.008 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 00:26:16.311 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 00:26:16.809 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 00:26:41.343 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 00:30:51.652 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 00:30:51.775 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9438751636039736, 'recall': 0.8452966014551031, 'f1': 0.8918680762172991}
# 2024-04-24 00:30:51.777 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 5.
# 2024-04-24 00:30:51.778 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 00:30:51.872 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 25895 sentences samples
# 2024-04-24 00:30:51.874 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 00:31:24.848 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 464199 rows, sort indx on certainty for 25903 sentences
# 2024-04-24 00:31:24.948 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 00:31:25.079 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 31074, remaining sentences: 20724
# 2024-04-24 00:31:36.772 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 00:37:35.143 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 00:37:35.750 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 00:38:00.960 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 00:42:13.128 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 00:42:13.253 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9456156506808802, 'recall': 0.847361099803908, 'f1': 0.8937938168688165}
# 2024-04-24 00:42:13.256 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 6.
# 2024-04-24 00:42:13.258 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 00:42:13.363 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 31074 sentences samples
# 2024-04-24 00:42:13.365 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 00:42:39.105 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 371248 rows, sort indx on certainty for 20724 sentences
# 2024-04-24 00:42:39.196 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 00:42:39.327 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 36253, remaining sentences: 15545
# 2024-04-24 00:42:54.040 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 00:49:53.682 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 00:49:54.351 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 00:50:18.580 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 00:54:30.513 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 00:54:30.626 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9461673958929634, 'recall': 0.8493875681911285, 'f1': 0.8951670371439913}
# 2024-04-24 00:54:30.628 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 7.
# 2024-04-24 00:54:30.631 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 00:54:30.725 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 36253 sentences samples
# 2024-04-24 00:54:30.727 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 00:54:50.734 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 277333 rows, sort indx on certainty for 15545 sentences
# 2024-04-24 00:54:50.815 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 00:54:50.948 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 41432, remaining sentences: 10366
# 2024-04-24 00:55:06.439 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 01:03:07.780 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 01:03:08.561 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 01:03:33.812 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 01:07:45.907 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 01:07:46.020 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9454757713401716, 'recall': 0.8539119652091881, 'f1': 0.8973621761071281}
# 2024-04-24 01:07:46.021 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 8.
# 2024-04-24 01:07:46.022 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 01:07:46.121 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 41432 sentences samples
# 2024-04-24 01:07:46.122 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 01:07:59.064 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 184160 rows, sort indx on certainty for 10366 sentences
# 2024-04-24 01:07:59.131 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 01:07:59.275 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 46611, remaining sentences: 5187
# 2024-04-24 01:08:17.455 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 01:17:14.844 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 01:17:15.758 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 01:17:41.302 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 01:21:54.130 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 01:21:54.240 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9462651395088887, 'recall': 0.8572525236621612, 'f1': 0.8995604003941432}
# 2024-04-24 01:21:54.242 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 9.
# 2024-04-24 01:21:54.244 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - Sample according to certainties
# 2024-04-24 01:21:54.340 | DEBUG    | ALLSampler_Sentence:sample_next_round:143 - Train model wrapper on sampled 46611 sentences samples
# 2024-04-24 01:21:54.342 | DEBUG    | ALLSampler_Sentence:sample_next_round:144 - Use trained model to estimate the remaining data certainty.
# 2024-04-24 01:22:00.769 | DEBUG    | ALLSampler_Sentence:sample_next_round:153 - remain 93768 rows, sort indx on certainty for 5187 sentences
# 2024-04-24 01:22:00.828 | DEBUG    | ALLSampler_Sentence:sample_next_round:169 - Update model with new sampled data
# 2024-04-24 01:22:00.974 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 51790, remaining sentences: 8
# 2024-04-24 01:22:01.008 | INFO     | ALLSampler_Sentence:simulate_rounds:97 - It's the last round, now add all docs to sampled.
# 2024-04-24 01:22:20.424 | DEBUG    | CRFWrapper_Sentence:fit:284 - Reset and train CRF model...
# 2024-04-24 01:32:25.724 | DEBUG    | CRFWrapper_Sentence:fit:292 - Training complete.
# 2024-04-24 01:32:26.795 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:352 - Predicting eval sents...
# 2024-04-24 01:32:52.329 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:356 - Calculate scores from bootstrapping 200 times
# 2024-04-24 01:37:04.286 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:365 - complete
# 2024-04-24 01:37:04.397 | DEBUG    | ALLSampler_Sentence:simulate_rounds:103 - {'precision': 0.9458741915098224, 'recall': 0.8602660573331704, 'f1': 0.9010392635896093}

# %%
def compute_mean_ci(scores):
    ave=np.mean(scores)
    ci=np.percentile(scores, [2.5, 97.5])
    return ave, ci

summary={'precision': [], 'pl':[], 'pu': [], 'recall': [], 'rl':[], 'ru': [], 'f1':[], 'fl':[], 'fu': []}
for s in scores:    
    for k,v in s.items():
        ave, (l, u)=compute_mean_ci(v)
        summary[k].append(ave)
        summary[k[0]+'l'].append(l)
        summary[k[0]+'u'].append(u)

# %%
pd.options.display.float_format='{:,.4f}'.format

# %%
pd.DataFrame(summary)
# Out:
#    precision     pl     pu  recall     rl     ru     f1     fl     fu
# 0     0.9461 0.9429 0.9494  0.7718 0.7655 0.7785 0.8501 0.8460 0.8547
# 1     0.9419 0.9387 0.9452  0.8132 0.8063 0.8200 0.8728 0.8689 0.8770
# 2     0.9430 0.9401 0.9459  0.8264 0.8206 0.8327 0.8808 0.8774 0.8850
# 3     0.9446 0.9413 0.9476  0.8359 0.8306 0.8412 0.8870 0.8830 0.8907
# 4     0.9439 0.9405 0.9474  0.8453 0.8402 0.8507 0.8919 0.8883 0.8956
# 5     0.9456 0.9420 0.9485  0.8474 0.8415 0.8522 0.8938 0.8899 0.8973
# 6     0.9462 0.9432 0.9490  0.8494 0.8444 0.8544 0.8952 0.8915 0.8988
# 7     0.9455 0.9424 0.9485  0.8539 0.8486 0.8589 0.8974 0.8936 0.9011
# 8     0.9463 0.9431 0.9489  0.8573 0.8528 0.8622 0.8996 0.8962 0.9029
# 9     0.9459 0.9424 0.9489  0.8603 0.8557 0.8653 0.9010 0.8981 0.9043

# %% [markdown]
# ## Bootstrap 3 different initials runs

# %%
boostrap_runs=3
total_round=10
logger.remove()
logger.add(sys.stderr, level='INFO')
# Out:
# 1

# %%
random.seed(14)
seeds=[random.randint(1,10000000) for  _ in range(boostrap_runs)]
seeds
# Out:
# [1792286, 8843471, 4142887]

# %%
all_scores=[]
for si, seed  in enumerate(seeds):
    logger.info(f'start run {si}.')
    crf_model=CRFModel(anno_types=annos)
    m_simulator=ModelSamplingSimulator(total_sents=train_df, 
                                   total_round=10, 
                                   modelWrapper=crf_model, 
                                   eval_sents=test_df, 
                                   init_seed=seed)  
    scores=m_simulator.simulate_rounds()
    all_scores.append(scores)
# Out:
# 2024-04-25 15:39:40.634 | INFO     | __main__:<module>:3 - start run 0.
# 2024-04-25 15:39:40.759 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 0.
# 2024-04-25 15:39:41.151 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-04-25 15:45:20.787 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 1.
# 2024-04-25 15:46:21.181 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 10358, remaining sentences: 41440
# 2024-04-25 15:53:05.117 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 2.
# 2024-04-25 15:53:58.390 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 15537, remaining sentences: 36261
# 2024-04-25 16:01:40.863 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 3.
# 2024-04-25 16:02:28.142 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 20716, remaining sentences: 31082
# 2024-04-25 16:11:22.938 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 4.
# 2024-04-25 16:12:05.160 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 25895, remaining sentences: 25903
# 2024-04-25 16:23:50.404 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 5.
# 2024-04-25 16:24:28.697 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 31074, remaining sentences: 20724
# 2024-04-25 16:36:01.142 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 6.
# 2024-04-25 16:36:28.325 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 36253, remaining sentences: 15545
# 2024-04-25 16:48:30.668 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 7.
# 2024-04-25 16:48:50.442 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 41432, remaining sentences: 10366
# 2024-04-25 17:01:40.616 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 8.
# 2024-04-25 17:01:53.619 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 46611, remaining sentences: 5187
# 2024-04-25 17:15:52.179 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 9.
# 2024-04-25 17:15:58.790 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 51790, remaining sentences: 8
# 2024-04-25 17:15:58.823 | INFO     | ALLSampler_Sentence:simulate_rounds:97 - It's the last round, now add all docs to sampled.
# 2024-04-25 17:31:09.068 | INFO     | __main__:<module>:3 - start run 1.
# 2024-04-25 17:31:09.175 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 0.
# 2024-04-25 17:31:09.547 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-04-25 17:36:48.931 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 1.
# 2024-04-25 17:37:48.791 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 10358, remaining sentences: 41440
# 2024-04-25 17:44:25.755 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 2.
# 2024-04-25 17:45:19.058 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 15537, remaining sentences: 36261
# 2024-04-25 17:52:58.534 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 3.
# 2024-04-25 17:53:45.060 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 20716, remaining sentences: 31082
# 2024-04-25 18:02:29.060 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 4.
# 2024-04-25 18:03:08.808 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 25895, remaining sentences: 25903
# 2024-04-25 18:12:54.461 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 5.
# 2024-04-25 18:13:27.832 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 31074, remaining sentences: 20724
# 2024-04-25 18:24:14.649 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 6.
# 2024-04-25 18:24:40.790 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 36253, remaining sentences: 15545
# 2024-04-25 18:36:28.123 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 7.
# 2024-04-25 18:36:47.650 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 41432, remaining sentences: 10366
# 2024-04-25 18:49:36.599 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 8.
# 2024-04-25 18:49:49.907 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 46611, remaining sentences: 5187
# 2024-04-25 19:03:50.833 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 9.
# 2024-04-25 19:03:57.654 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 51790, remaining sentences: 8
# 2024-04-25 19:03:57.687 | INFO     | ALLSampler_Sentence:simulate_rounds:97 - It's the last round, now add all docs to sampled.
# 2024-04-25 19:19:02.569 | INFO     | __main__:<module>:3 - start run 2.
# 2024-04-25 19:19:02.683 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 0.
# 2024-04-25 19:19:03.062 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-04-25 19:24:42.611 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 1.
# 2024-04-25 19:25:44.257 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 10358, remaining sentences: 41440
# 2024-04-25 19:32:57.510 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 2.
# 2024-04-25 19:33:53.656 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 15537, remaining sentences: 36261
# 2024-04-25 19:41:48.092 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 3.
# 2024-04-25 19:42:36.144 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 20716, remaining sentences: 31082
# 2024-04-25 19:51:24.046 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 4.
# 2024-04-25 19:52:05.521 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 25895, remaining sentences: 25903
# 2024-04-25 20:02:08.445 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 5.
# 2024-04-25 20:02:41.253 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 31074, remaining sentences: 20724
# 2024-04-25 20:13:21.295 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 6.
# 2024-04-25 20:13:48.197 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 36253, remaining sentences: 15545
# 2024-04-25 20:25:40.390 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 7.
# 2024-04-25 20:26:00.032 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 41432, remaining sentences: 10366
# 2024-04-25 20:38:48.200 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 8.
# 2024-04-25 20:39:01.458 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 46611, remaining sentences: 5187
# 2024-04-25 20:53:11.093 | INFO     | ALLSampler_Sentence:simulate_rounds:92 - simulate round 9.
# 2024-04-25 20:53:17.882 | INFO     | ALLSampler_Sentence:keep_sample:82 - current sampled sentences: 51790, remaining sentences: 8
# 2024-04-25 20:53:17.915 | INFO     | ALLSampler_Sentence:simulate_rounds:97 - It's the last round, now add all docs to sampled.

# %%
joblib.dump(all_scores, r'../data/n2c2/scores_sentence_sampling/ner_crf_scores_sentenceSampling.joblib')
# Out:
# ['../data/n2c2/scores_sentence_sampling/ner_crf_scores_sentenceSampling.joblib']
