# %%
import sklearn_crfsuite
from sklearn_crfsuite.metrics import flat_f1_score
from sklearn_crfsuite import CRF
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from spacy.lang.en import English
from spacy import displacy
from pathlib import Path
import joblib
from spacy.tokens import Doc
from typing import List
import random
from statistics import mean, stdev
from loguru import logger
import sys
import spacy
from medspacy_io.reader.brat_reader import BratDocReader, BratDirReader
import medspacy

# %% [markdown]
# ## initialize brat reader

# %%
cleaned_train_dir=r'..\data\n2c2\cleaned_training'
cleaned_test_dir=r'..\data\n2c2\cleaned_test'
Path(cleaned_train_dir).exists(), Path(cleaned_test_dir).exists()
# Out:
# (True, True)

# %%
nlp=spacy.load('en_core_web_sm', disable=['ner'])

# %%
dir_reader = BratDirReader(nlp=nlp, schema_file=str(Path(cleaned_train_dir, 'annotation.conf')), support_overlap=True)

# %% [markdown]
# ## Read eHOST annotations | load from pickles

# %%
pickle_file= r'..\data\n2c2\spacy_docs.joblib'

# %%
if not Path(pickle_file).exists():
    train_docs=dir_reader.read(txt_dir=cleaned_train_dir)
    test_docs=dir_reader.read(txt_dir=cleaned_test_dir)
    print(len(train_docs), len(test_docs))
    joblib.dump((train_docs, test_docs), pickle_file)
else:
    print(f'{pickle_file} already exists, load them directly')
    # before load from pickle, initiate EhostDirReader or EhostDocReader first, because some Doc extension used to store meta data will not be automatically recreated by loading.
    train_docs, test_docs=joblib.load(pickle_file)
# Out:
# ..\data\n2c2\spacy_docs.joblib already exists, load them directly

# %%
len(train_docs), len(test_docs)
# Out:
# (303, 202)

# %% [markdown]
# ## CRF Wrapper (only use for eval)

# %%
from CRFWrapper_Sentence import spans_to_bio, convert_docs, word2features, sent2features,compute_metrics_and_averages,  CRFModel

# %%
## Get all annotation types: 
annos=set()
for d in train_docs:
    for anno in d.spans.keys():
        annos.add(anno)
print(annos)
# Out:
# {'Strength', 'ADE', 'Reason', 'Drug', 'Frequency', 'Route', 'Dosage', 'Form', 'Duration'}

# %%
crf_model=CRFModel(anno_types=annos)

# %% [markdown]
# ## converting docs into sentence level dataframe

# %%
from ALLSampler_Sentence import SamplingSimulator, ModelSamplingSimulator, VBSamplingSimulator, convert_docs_medspacyIOvec

# %%
# get sentence label from docs
sdf_labels_train=convert_docs_medspacyIOvec(train_docs)
sdf_labels_train
# Out:
#                                                 sentence       concept     y  \
# 0      [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1      While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2      While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3      While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4      While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                  ...           ...   ...
# 90405                                   [**Name (NI) **]                 NEG
# 90406                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 90407  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
# 90408                                                 3.                 NEG
# 90409                                                 6.                 NEG
#
#          doc_name
# 0      100035.txt
# 1      100035.txt
# 2      100035.txt
# 3      100035.txt
# 4      100035.txt
# ...           ...
# 90405  198406.txt
# 90406  198406.txt
# 90407  198406.txt
# 90408  198406.txt
# 90409  198406.txt
#
# [90410 rows x 4 columns]

# %%
# get token level label from docs
_, train_df=convert_docs(train_docs, anno_types=annos)
_, test_df=convert_docs(test_docs, anno_types=annos)

# %%
train_df
# Out:
#       sentence_id    doc_name         token label  \
# 0               0  100035.txt     Admission     O
# 1               0  100035.txt          Date     O
# 2               0  100035.txt             :     O
# 3               1  100035.txt             [     O
# 4               1  100035.txt             *     O
# ...           ...         ...           ...   ...
# 3151       929927  198406.txt      Followup     O
# 3152       929927  198406.txt  Instructions     O
# 3153       929927  198406.txt             :     O
# 3154       929927  198406.txt            \n     O
# 3155       929927  198406.txt      Deceased     O
#
#                                                sentence
# 0                                     Admission Date:
# 1                                     Admission Date:
# 2                                     Admission Date:
# 3     [**2115-2-22**]              Discharge Date:  ...
# 4     [**2115-2-22**]              Discharge Date:  ...
# ...                                                 ...
# 3151  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3152  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3153  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3154  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
# 3155  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
# [932906 rows x 5 columns]

# %%
# embedding for unique sentence
pickle_embedding_file= r'..\data\n2c2\embedding_df_uniqueSentID.joblib' 
embedding_df=joblib.load(pickle_embedding_file)

# %%
embedding_df
# Out:
#       sentence_id                                           sentence  \
# 0               0                                  Admission Date:
# 3               1  [**2115-2-22**]              Discharge Date:  ...
# 35              2  [**2078-8-9**]             Sex:   M\n\nService...
# 113             3  [**Known lastname 3234**] is a 36 year old gen...
# 163             4  The patient initially presented to LGH ED with...
# ...           ...                                                ...
# 3059       929923  Cyanocobalamin 1,000 mcg/mL Injection once a m...
# 3071       929924  Lorazepam 0.25 QAM, O.25 QPM, 0.5 mg QHS\n8 Ca...
# 3086       929925                              Cream Topical TID\n9.
# 3092       929926                  Acetaminophen 1000 mg PO Q6H\n10.
# 3100       929927  Mirtazapine 15 mg PO QHS\n\n\nDischarge Medica...
#
#                                               embedding
# 0     [0.026282, 0.03218903, -0.022386529, 0.0493732...
# 3     [0.016159855, 0.042264156, -0.018290585, -0.05...
# 35    [0.025958579, -0.05749655, 0.012378361, -0.009...
# 113   [0.023170307, 0.03989108, 0.026217388, -0.0272...
# 163   [0.008176211, -0.06342948, 0.048615105, -0.045...
# ...                                                 ...
# 3059  [0.050521564, -0.08905716, -0.0019493615, -0.0...
# 3071  [-0.030010266, -0.062390286, 0.00167252, 0.016...
# 3086  [0.026732022, -0.04987913, 0.024520764, -0.016...
# 3092  [-0.017295217, -0.10513715, -0.0030776137, -0....
# 3100  [0.02337662, 0.021309359, 0.039473698, -0.0429...
#
# [51798 rows x 3 columns]

# %%
sdf_labels_sid = sdf_labels_train.merge(embedding_df, how='inner', on='sentence')

# %%
sdf_labels_sid
# Out:
#                                                  sentence       concept     y  \
# 0       [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1       While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2       While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3       While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4       While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                   ...           ...   ...
# 638687  Patient had some cardiac enzyme leaks\nduring ...                 NEG
# 638688  Patient was given cardiac healthy diet during ...                 NEG
# 638689  # CODE: DNR/DNI (discussed with patient and so...                 NEG
# 638690                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 638691  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
#
#           doc_name  sentence_id  \
# 0       100035.txt            2
# 1       100035.txt            5
# 2       100035.txt            5
# 3       100035.txt            5
# 4       100035.txt            5
# ...            ...          ...
# 638687  198406.txt       929907
# 638688  198406.txt       929910
# 638689  198406.txt       929911
# 638690  198406.txt       929914
# 638691  198406.txt       929915
#
#                                                 embedding
# 0       [0.025958579, -0.05749655, 0.012378361, -0.009...
# 1       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 2       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 3       [0.038356796, -0.054362558, 0.028156247, -0.02...
# 4       [0.038356796, -0.054362558, 0.028156247, -0.02...
# ...                                                   ...
# 638687  [0.02065785, -0.06587324, 0.055154495, 0.01074...
# 638688  [0.030450102, -0.042418838, 0.00325665, 0.0384...
# 638689  [0.023342747, 0.013347558, -0.01095362, -0.052...
# 638690  [0.02003492, 0.029056935, -0.0140215475, 0.007...
# 638691  [0.013550696, -0.004964338, -0.024216548, -0.0...
#
# [638692 rows x 6 columns]

# %%
train_sentID_list = train_df['sentence_id'].to_list()
train_sentID_set = set(train_sentID_list)
train_sentID_uniqList = list(train_sentID_set)
test_sentID_list = test_df['sentence_id'].to_list()
test_sentID_set = set(test_sentID_list)
test_sentID_uniqList = list(test_sentID_set)
print(len(train_sentID_uniqList), len(test_sentID_uniqList))
# Out:
# 51798 34334

# %%
# 10 round, how many sample in each round
int(1.0*len(train_sentID_uniqList)/10)
# Out:
# 5179

# %%
# only input some columns from sentence label dataframe
sdf_labels_sid[['sentence','concept', 'y', 'doc_name','sentence_id']]
# Out:
#                                                  sentence       concept     y  \
# 0       [**2078-8-9**]             Sex:   M\n\nService...       Vicodin  Drug
# 1       While at the OSH, he received CTX,\nazithromyc...           CTX  Drug
# 2       While at the OSH, he received CTX,\nazithromyc...  azithromycin  Drug
# 3       While at the OSH, he received CTX,\nazithromyc...   epinephrine  Drug
# 4       While at the OSH, he received CTX,\nazithromyc...    solumedrol  Drug
# ...                                                   ...           ...   ...
# 638687  Patient had some cardiac enzyme leaks\nduring ...                 NEG
# 638688  Patient was given cardiac healthy diet during ...                 NEG
# 638689  # CODE: DNR/DNI (discussed with patient and so...                 NEG
# 638690                  [**Telephone/Fax (1) 92787**](H),                 NEG
# 638691  [**Telephone/Fax (1) 92788**](C)\n\n\nMedicati...                 NEG
#
#           doc_name  sentence_id
# 0       100035.txt            2
# 1       100035.txt            5
# 2       100035.txt            5
# 3       100035.txt            5
# 4       100035.txt            5
# ...            ...          ...
# 638687  198406.txt       929907
# 638688  198406.txt       929910
# 638689  198406.txt       929911
# 638690  198406.txt       929914
# 638691  198406.txt       929915
#
# [638692 rows x 5 columns]

# %% [markdown]
# ## Define sampling simulator

# %%
logger.remove()
logger.add(sys.stderr, level='INFO')
logger.add(sys.stderr, level='DEBUG')
# Out:
# 2

# %%
faiss_index_path= r'..\data\n2c2\faiss_index_st768' #FAISS indexing regenerated for unique sentence embedding

# %%
pickle_embedding_file=  r'..\data\n2c2\embedding_df_uniqueSentID.joblib' #unique sentence embeddings
embedding_df=joblib.load(pickle_embedding_file)
vb_simulator=VBSamplingSimulator(total_sents=train_df, 
                                 total_round=10, 
                                 modelWrapper=crf_model, 
                                 eval_sents=test_df, 
                                 init_seed=14, 
                                 faiss_index_path=faiss_index_path, 
                                 embedding_df=embedding_df,
                                 sdf_labels= sdf_labels_sid[['sentence','concept', 'y', 'doc_name','sentence_id']],
                                 min_dist_diff=True
                                )
# Out:
# 2024-05-16 23:25:55.808 | DEBUG    | ALLSampler_Sentence:__init__:69 - num per found unique sent: 5179
# 2024-05-16 23:25:55.815 | DEBUG    | ALLSampler_Sentence:__init__:224 - Loading index...
# 2024-05-16 23:25:56.817 | DEBUG    | ALLSampler_Sentence:__init__:226 - done

# %% [markdown]
# ## run test

# %%
scores=vb_simulator.simulate_rounds(boostrap_times=3)

# %%
def compute_mean_ci(scores):
    ave=np.mean(scores)
    ci=np.percentile(scores, [2.5, 97.5])
    return ave, ci

summary={'precision': [], 'pl':[], 'pu': [], 'recall': [], 'rl':[], 'ru': [], 'f1':[], 'fl':[], 'fu': []}
for s in scores:    
    for k,v in s.items():
        ave, (l, u)=compute_mean_ci(v)
        summary[k].append(ave)
        summary[k[0]+'l'].append(l)
        summary[k[0]+'u'].append(u)

# %%
pd.options.display.float_format='{:,.5f}'.format
pd.DataFrame(summary)

# %% [markdown]
# ## bootstrap 3 runs

# %%
logger.remove()
logger.add(sys.stderr, level='INFO')
logger.add(sys.stderr, level='DEBUG')
# Out:
# 4

# %%
boostrap_runs=3
total_round=10

# %%
random.seed(14)
seeds=[random.randint(1,10000000) for  _ in range(boostrap_runs)]
seeds
# Out:
# [1792286, 8843471, 4142887]

# %%
all_scores=[]
embedding_df=joblib.load(pickle_embedding_file)
for si, seed  in enumerate(seeds):
    logger.info(f'start run {si}.')
    pickle_embedding_file= r'..\data\n2c2\embedding_df_uniqueSentID.joblib' 
    crf_model=CRFModel(anno_types=annos)
    vb_simulator=VBSamplingSimulator(total_sents=train_df, 
                                 total_round=10, 
                                 modelWrapper=crf_model, 
                                 eval_sents=test_df, 
                                 init_seed=seed, 
                                 faiss_index_path=faiss_index_path, 
                                 embedding_df=embedding_df,
                                 sdf_labels=sdf_labels_sid[['sentence','concept', 'y', 'doc_name','sentence_id']],
                                 min_dist_diff=True
                                )
    #v_simulator=VBSamplingSimulator(train_docs, 
    #                                total_round=10, 
    #                                modelWrapper=crf_model, 
    #                                eval_docs=test_docs, 
    #                                init_seed=seed, 
    #                                faiss_index_path=faiss_index_path, 
    #                                embedding_df=embedding_df, 
    #                                min_dist_diff=True)
    scores=vb_simulator.simulate_rounds(boostrap_times=200)
    all_scores.append(scores)
# Out:
# 2024-05-16 23:27:58.689 | INFO     | __main__:<module>:4 - start run 0.
# 2024-05-16 23:27:58.689 | INFO     | __main__:<module>:4 - start run 0.
# 2024-05-16 23:27:58.846 | DEBUG    | ALLSampler_Sentence:__init__:69 - num per found unique sent: 5179
# 2024-05-16 23:27:58.854 | DEBUG    | ALLSampler_Sentence:__init__:224 - Loading index...
# 2024-05-16 23:27:59.333 | DEBUG    | ALLSampler_Sentence:__init__:226 - done
# 2024-05-16 23:27:59.469 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 0.
# 2024-05-16 23:27:59.469 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 0.
# 2024-05-16 23:27:59.472 | DEBUG    | ALLSampler_Sentence:keep_sample:78 - The first round sampling will be random
# 2024-05-16 23:27:59.883 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-05-16 23:27:59.883 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 5179, remaining sentences: 46619
# 2024-05-16 23:28:01.838 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-16 23:28:59.085 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-16 23:28:59.152 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-16 23:29:24.428 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-16 23:33:40.129 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-16 23:33:40.245 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9403552442593025, 'recall': 0.7889231571933004, 'f1': 0.8580046400134609}
# 2024-05-16 23:33:40.247 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 1.
# 2024-05-16 23:33:40.247 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 1.
# 2024-05-16 23:33:40.252 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-16 23:33:40.342 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-16 23:34:21.578 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-16 23:34:21.582 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-16 23:34:21.718 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-16 23:34:21.718 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-16 23:34:21.721 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-16 23:34:21.877 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:21.913 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-16 23:34:22.088 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:22.127 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-16 23:34:22.282 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:22.317 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-16 23:34:22.480 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:22.517 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-16 23:34:22.684 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:22.723 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-16 23:34:22.864 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:22.901 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-16 23:34:23.056 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:23.094 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-16 23:34:23.252 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:23.286 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-16 23:34:23.360 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:23.446 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-16 23:34:23.607 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:34:23.645 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-16 23:34:23.645 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-16 23:34:23.650 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-16 23:34:25.194 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-16 23:34:26.506 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37665
# 2024-05-16 23:34:26.529 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 33905
# 2024-05-16 23:34:26.533 | DEBUG    | ALLSampler_Sentence:sample_next_round:364 - NEW SAMPLED UNIQUE SENT REACH NUM_PER_ROUND---:
# 2024-05-16 23:34:26.535 | DEBUG    | ALLSampler_Sentence:sample_next_round:365 - num per found 5179
# 2024-05-16 23:34:26.536 | DEBUG    | ALLSampler_Sentence:sample_next_round:366 - new_sampled_sentID: 5179
# 2024-05-16 23:34:26.539 | DEBUG    | ALLSampler_Sentence:sample_next_round:367 - --------------------------
# 2024-05-16 23:34:26.625 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 5179
# 2024-05-16 23:34:26.627 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 41440
# 2024-05-16 23:34:26.802 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 92500, old remaining data 840406
# 2024-05-16 23:34:26.804 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 103204, new remaining data 737202
# 2024-05-16 23:34:26.821 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 195704, new remaining data 737202
# 2024-05-16 23:34:26.998 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 10358, remaining sentences: 41440
# 2024-05-16 23:34:26.998 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 10358, remaining sentences: 41440
# 2024-05-16 23:34:31.213 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-16 23:36:37.261 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-16 23:36:37.446 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-16 23:37:03.275 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-16 23:41:20.111 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-16 23:41:20.221 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9386447284440059, 'recall': 0.8232673316947323, 'f1': 0.8771750078277722}
# 2024-05-16 23:41:20.223 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 2.
# 2024-05-16 23:41:20.223 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 2.
# 2024-05-16 23:41:20.226 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-16 23:41:20.322 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-16 23:42:51.144 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-16 23:42:51.151 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-16 23:42:51.288 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-16 23:42:51.288 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-16 23:42:51.290 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-16 23:42:51.460 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:51.497 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-16 23:42:51.578 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:51.653 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-16 23:42:51.811 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:51.850 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-16 23:42:52.013 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:52.053 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-16 23:42:52.172 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:52.223 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-16 23:42:52.390 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:52.428 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-16 23:42:52.595 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:52.633 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-16 23:42:52.768 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:52.807 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-16 23:42:52.966 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:53.004 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-16 23:42:53.171 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:42:53.211 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-16 23:42:53.211 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-16 23:42:53.216 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-16 23:42:54.729 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-16 23:42:56.032 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37327
# 2024-05-16 23:42:56.069 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 28551
# 2024-05-16 23:42:56.074 | DEBUG    | ALLSampler_Sentence:sample_next_round:364 - NEW SAMPLED UNIQUE SENT REACH NUM_PER_ROUND---:
# 2024-05-16 23:42:56.077 | DEBUG    | ALLSampler_Sentence:sample_next_round:365 - num per found 5179
# 2024-05-16 23:42:56.078 | DEBUG    | ALLSampler_Sentence:sample_next_round:366 - new_sampled_sentID: 5179
# 2024-05-16 23:42:56.079 | DEBUG    | ALLSampler_Sentence:sample_next_round:367 - --------------------------
# 2024-05-16 23:42:56.158 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 5179
# 2024-05-16 23:42:56.160 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 36261
# 2024-05-16 23:42:56.312 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 195704, old remaining data 737202
# 2024-05-16 23:42:56.313 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 105301, new remaining data 631901
# 2024-05-16 23:42:56.338 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 301005, new remaining data 631901
# 2024-05-16 23:42:56.510 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 15537, remaining sentences: 36261
# 2024-05-16 23:42:56.510 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 15537, remaining sentences: 36261
# 2024-05-16 23:43:02.942 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-16 23:46:11.645 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-16 23:46:11.903 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-16 23:46:38.037 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-16 23:50:52.971 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-16 23:50:53.077 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9398233478648379, 'recall': 0.8391648255529749, 'f1': 0.886643961104711}
# 2024-05-16 23:50:53.079 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 3.
# 2024-05-16 23:50:53.079 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 3.
# 2024-05-16 23:50:53.082 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-16 23:50:53.171 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-16 23:53:08.140 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-16 23:53:08.147 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-16 23:53:08.284 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-16 23:53:08.284 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-16 23:53:08.287 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-16 23:53:08.472 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:08.508 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-16 23:53:08.662 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:08.700 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-16 23:53:08.861 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:08.899 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-16 23:53:09.065 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:09.102 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-16 23:53:09.267 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:09.307 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-16 23:53:09.471 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:09.510 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-16 23:53:09.674 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:09.711 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-16 23:53:09.857 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:09.893 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-16 23:53:10.050 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:10.087 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-16 23:53:10.252 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-16 23:53:10.290 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-16 23:53:10.290 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-16 23:53:10.293 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-16 23:53:11.794 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-16 23:53:13.092 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37553
# 2024-05-16 23:53:13.137 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 23659
# 2024-05-16 23:53:13.143 | DEBUG    | ALLSampler_Sentence:sample_next_round:364 - NEW SAMPLED UNIQUE SENT REACH NUM_PER_ROUND---:
# 2024-05-16 23:53:13.145 | DEBUG    | ALLSampler_Sentence:sample_next_round:365 - num per found 5179
# 2024-05-16 23:53:13.146 | DEBUG    | ALLSampler_Sentence:sample_next_round:366 - new_sampled_sentID: 5179
# 2024-05-16 23:53:13.147 | DEBUG    | ALLSampler_Sentence:sample_next_round:367 - --------------------------
# 2024-05-16 23:53:13.214 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 5179
# 2024-05-16 23:53:13.216 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 31082
# 2024-05-16 23:53:13.345 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 301005, old remaining data 631901
# 2024-05-16 23:53:13.347 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 102633, new remaining data 529268
# 2024-05-16 23:53:13.377 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 403638, new remaining data 529268
# 2024-05-16 23:53:13.557 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 20716, remaining sentences: 31082
# 2024-05-16 23:53:13.557 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 20716, remaining sentences: 31082
# 2024-05-16 23:53:21.709 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-16 23:57:42.917 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-16 23:57:43.259 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-16 23:58:09.939 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 00:02:27.295 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 00:02:27.401 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9422598957111612, 'recall': 0.8462861495049739, 'f1': 0.8916954780914935}
# 2024-05-17 00:02:27.403 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 4.
# 2024-05-17 00:02:27.403 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 4.
# 2024-05-17 00:02:27.406 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 00:02:27.498 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 00:05:31.422 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 00:05:31.431 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 00:05:31.567 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:05:31.567 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:05:31.570 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 00:05:31.740 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:31.777 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 00:05:31.869 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:31.943 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 00:05:32.101 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:32.138 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 00:05:32.305 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:32.343 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 00:05:32.461 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:32.517 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 00:05:32.661 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:32.697 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 00:05:32.867 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:32.904 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 00:05:33.057 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:33.095 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 00:05:33.258 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:33.294 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 00:05:33.461 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:05:33.499 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:05:33.499 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:05:33.503 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 00:05:35.060 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 00:05:36.353 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37595
# 2024-05-17 00:05:36.409 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 18622
# 2024-05-17 00:05:36.413 | DEBUG    | ALLSampler_Sentence:sample_next_round:364 - NEW SAMPLED UNIQUE SENT REACH NUM_PER_ROUND---:
# 2024-05-17 00:05:36.415 | DEBUG    | ALLSampler_Sentence:sample_next_round:365 - num per found 5179
# 2024-05-17 00:05:36.416 | DEBUG    | ALLSampler_Sentence:sample_next_round:366 - new_sampled_sentID: 5179
# 2024-05-17 00:05:36.417 | DEBUG    | ALLSampler_Sentence:sample_next_round:367 - --------------------------
# 2024-05-17 00:05:36.476 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 5179
# 2024-05-17 00:05:36.477 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 25903
# 2024-05-17 00:05:36.589 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 403638, old remaining data 529268
# 2024-05-17 00:05:36.591 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 104525, new remaining data 424743
# 2024-05-17 00:05:36.628 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 508163, new remaining data 424743
# 2024-05-17 00:05:36.800 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 25895, remaining sentences: 25903
# 2024-05-17 00:05:36.800 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 25895, remaining sentences: 25903
# 2024-05-17 00:05:47.266 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 00:11:07.712 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 00:11:08.176 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 00:11:34.107 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 00:15:48.103 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 00:15:48.198 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9438268646110857, 'recall': 0.8483222739970974, 'f1': 0.8935271882973896}
# 2024-05-17 00:15:48.200 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 5.
# 2024-05-17 00:15:48.200 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 5.
# 2024-05-17 00:15:48.202 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 00:15:48.299 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 00:19:39.558 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 00:19:39.570 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 00:19:39.706 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:19:39.706 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:19:39.709 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 00:19:39.869 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:39.905 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 00:19:40.080 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:40.125 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 00:19:40.295 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:40.333 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 00:19:40.477 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:40.514 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 00:19:40.721 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:40.762 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 00:19:40.921 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:40.957 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 00:19:41.121 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:41.160 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 00:19:41.326 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:41.363 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 00:19:41.527 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:41.565 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 00:19:41.674 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:19:41.736 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:19:41.736 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:19:41.739 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 00:19:43.258 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 00:19:44.542 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37703
# 2024-05-17 00:19:44.609 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 13549
# 2024-05-17 00:19:44.614 | DEBUG    | ALLSampler_Sentence:sample_next_round:364 - NEW SAMPLED UNIQUE SENT REACH NUM_PER_ROUND---:
# 2024-05-17 00:19:44.615 | DEBUG    | ALLSampler_Sentence:sample_next_round:365 - num per found 5179
# 2024-05-17 00:19:44.616 | DEBUG    | ALLSampler_Sentence:sample_next_round:366 - new_sampled_sentID: 5179
# 2024-05-17 00:19:44.617 | DEBUG    | ALLSampler_Sentence:sample_next_round:367 - --------------------------
# 2024-05-17 00:19:44.664 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 5179
# 2024-05-17 00:19:44.666 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 20724
# 2024-05-17 00:19:44.770 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 508163, old remaining data 424743
# 2024-05-17 00:19:44.771 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 102105, new remaining data 322638
# 2024-05-17 00:19:44.823 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 610268, new remaining data 322638
# 2024-05-17 00:19:44.999 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 31074, remaining sentences: 20724
# 2024-05-17 00:19:44.999 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 31074, remaining sentences: 20724
# 2024-05-17 00:19:57.685 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 00:26:25.428 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 00:26:26.013 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 00:26:51.682 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 00:31:07.156 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 00:31:07.258 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9436118800805278, 'recall': 0.8548009279992747, 'f1': 0.8970115652253625}
# 2024-05-17 00:31:07.260 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 6.
# 2024-05-17 00:31:07.260 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 6.
# 2024-05-17 00:31:07.263 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 00:31:07.357 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 00:35:40.155 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 00:35:40.169 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 00:35:40.319 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:35:40.319 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:35:40.322 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 00:35:40.427 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:40.501 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 00:35:40.658 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:40.697 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 00:35:40.862 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:40.899 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 00:35:41.036 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:41.076 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 00:35:41.262 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:41.304 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 00:35:41.470 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:41.509 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 00:35:41.630 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:41.679 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 00:35:41.847 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:41.885 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 00:35:42.051 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:42.088 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 00:35:42.222 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:35:42.262 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:35:42.262 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:35:42.266 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 00:35:43.826 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 00:35:45.136 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37783
# 2024-05-17 00:35:45.209 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 8525
# 2024-05-17 00:35:45.214 | DEBUG    | ALLSampler_Sentence:sample_next_round:364 - NEW SAMPLED UNIQUE SENT REACH NUM_PER_ROUND---:
# 2024-05-17 00:35:45.215 | DEBUG    | ALLSampler_Sentence:sample_next_round:365 - num per found 5179
# 2024-05-17 00:35:45.216 | DEBUG    | ALLSampler_Sentence:sample_next_round:366 - new_sampled_sentID: 5179
# 2024-05-17 00:35:45.218 | DEBUG    | ALLSampler_Sentence:sample_next_round:367 - --------------------------
# 2024-05-17 00:35:45.258 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 5179
# 2024-05-17 00:35:45.259 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 15545
# 2024-05-17 00:35:45.336 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 610268, old remaining data 322638
# 2024-05-17 00:35:45.338 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 100125, new remaining data 222513
# 2024-05-17 00:35:45.398 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 710393, new remaining data 222513
# 2024-05-17 00:35:45.573 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 36253, remaining sentences: 15545
# 2024-05-17 00:35:45.573 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 36253, remaining sentences: 15545
# 2024-05-17 00:36:00.330 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 00:43:34.302 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 00:43:34.969 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 00:44:01.412 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 00:48:14.182 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 00:48:14.288 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.945163275082316, 'recall': 0.8579775891476962, 'f1': 0.8994603388660337}
# 2024-05-17 00:48:14.290 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 7.
# 2024-05-17 00:48:14.290 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 7.
# 2024-05-17 00:48:14.292 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 00:48:14.385 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 00:53:29.762 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 00:53:29.778 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 00:53:29.916 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:53:29.916 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 00:53:29.919 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 00:53:30.093 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:30.129 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 00:53:30.292 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:30.331 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 00:53:30.482 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:30.518 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 00:53:30.682 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:30.721 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 00:53:30.885 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:30.926 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 00:53:31.009 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:31.092 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 00:53:31.261 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:31.300 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 00:53:31.463 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:31.501 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 00:53:31.578 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:31.670 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 00:53:31.839 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 00:53:31.876 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:53:31.876 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 00:53:31.880 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 00:53:33.393 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 00:53:34.688 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37759
# 2024-05-17 00:53:34.772 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 3499
# 2024-05-17 00:53:34.798 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 3499
# 2024-05-17 00:53:34.799 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 12046
# 2024-05-17 00:53:34.856 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 710393, old remaining data 222513
# 2024-05-17 00:53:34.858 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 71504, new remaining data 151009
# 2024-05-17 00:53:34.926 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 781897, new remaining data 151009
# 2024-05-17 00:53:35.097 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39752, remaining sentences: 12046
# 2024-05-17 00:53:35.097 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39752, remaining sentences: 12046
# 2024-05-17 00:53:52.021 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 01:02:07.927 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 01:02:08.664 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 01:02:33.640 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 01:06:48.778 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 01:06:48.879 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9435413676471236, 'recall': 0.8594947124057626, 'f1': 0.8995569162806177}
# 2024-05-17 01:06:48.881 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 8.
# 2024-05-17 01:06:48.881 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 8.
# 2024-05-17 01:06:48.884 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 01:06:48.973 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 01:12:34.731 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 01:12:34.749 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 01:12:34.888 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 01:12:34.888 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 01:12:34.892 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 01:12:35.076 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 01:12:35.114 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 01:12:35.270 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 01:12:35.305 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 01:12:35.472 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 01:12:35.508 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 01:12:35.674 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 01:12:35.710 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 01:12:35.875 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 01:12:35.913 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 01:12:36.078 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 01:12:36.116 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# ...
# 2024-05-17 05:29:27.012 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 05:29:27.178 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:29:27.213 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 05:29:27.287 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:29:27.384 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 05:29:27.553 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:29:27.594 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 05:29:27.756 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:29:27.793 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 05:29:27.953 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:29:27.988 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 05:29:28.146 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:29:28.183 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 05:29:28.183 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 05:29:28.188 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 05:29:29.708 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 05:29:30.979 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37754
# 2024-05-17 05:29:31.064 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 3473
# 2024-05-17 05:29:31.090 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 3473
# 2024-05-17 05:29:31.091 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 12072
# 2024-05-17 05:29:31.141 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 711289, old remaining data 221617
# 2024-05-17 05:29:31.143 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 69942, new remaining data 151675
# 2024-05-17 05:29:31.197 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 781231, new remaining data 151675
# 2024-05-17 05:29:31.372 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39726, remaining sentences: 12072
# 2024-05-17 05:29:31.372 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39726, remaining sentences: 12072
# 2024-05-17 05:29:47.315 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 05:38:05.395 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 05:38:06.071 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 05:38:32.562 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 05:42:48.470 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 05:42:48.573 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9459895011902016, 'recall': 0.8585914643456419, 'f1': 0.9001717970477148}
# 2024-05-17 05:42:48.575 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 8.
# 2024-05-17 05:42:48.575 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 8.
# 2024-05-17 05:42:48.577 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 05:42:48.668 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 05:48:26.146 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 05:48:26.163 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 05:48:26.297 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 05:48:26.297 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 05:48:26.301 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 05:48:26.465 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:26.502 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 05:48:26.637 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:26.677 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 05:48:26.840 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:26.895 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 05:48:27.060 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:27.113 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 05:48:27.233 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:27.284 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 05:48:27.450 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:27.487 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 05:48:27.653 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:27.691 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 05:48:27.828 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:27.867 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 05:48:28.034 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:28.084 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 05:48:28.247 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 05:48:28.284 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 05:48:28.284 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 05:48:28.289 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 05:48:29.799 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 05:48:31.066 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37788
# 2024-05-17 05:48:31.161 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 102
# 2024-05-17 05:48:31.177 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 102
# 2024-05-17 05:48:31.179 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 11970
# 2024-05-17 05:48:31.214 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 781231, old remaining data 151675
# 2024-05-17 05:48:31.217 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 1675, new remaining data 150000
# 2024-05-17 05:48:31.272 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 782906, new remaining data 150000
# 2024-05-17 05:48:31.444 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39828, remaining sentences: 11970
# 2024-05-17 05:48:31.444 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39828, remaining sentences: 11970
# 2024-05-17 05:48:48.195 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 05:57:07.377 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 05:57:08.057 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 05:57:33.906 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 06:01:49.475 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 06:01:49.573 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9456070664140254, 'recall': 0.8586812526809563, 'f1': 0.9000479143440964}
# 2024-05-17 06:01:49.574 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 9.
# 2024-05-17 06:01:49.574 | INFO     | ALLSampler_Sentence:simulate_rounds:95 - simulate round 9.
# 2024-05-17 06:01:49.577 | DEBUG    | ALLSampler_Sentence:keep_sample:81 - Sample according to certainties
# 2024-05-17 06:01:49.665 | DEBUG    | ALLSampler_Sentence:sample_next_round:316 - Calculating centroids...
# 2024-05-17 06:07:27.317 | DEBUG    | ALLSampler_Sentence:fit:262 - 10 centroids detected from the given sampled_docs
# 2024-05-17 06:07:27.332 | DEBUG    | ALLSampler_Sentence:sample_next_round:319 - Searching from the vector index...
# 2024-05-17 06:07:27.469 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 06:07:27.469 | INFO     | ALLSampler_Sentence:sample_next_round:335 - AFTER FAISS INDEXING distance shape: (929928, 10), max to retrieve 46620 sentences
# 2024-05-17 06:07:27.472 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: ADE
# 2024-05-17 06:07:27.636 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:27.672 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Dosage
# 2024-05-17 06:07:27.831 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:27.869 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Drug
# 2024-05-17 06:07:28.035 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:28.072 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Duration
# 2024-05-17 06:07:28.238 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:28.276 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Form
# 2024-05-17 06:07:28.426 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:28.461 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Frequency
# 2024-05-17 06:07:28.630 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:28.667 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: NEG
# 2024-05-17 06:07:28.831 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:28.868 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Reason
# 2024-05-17 06:07:29.020 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:29.057 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Route
# 2024-05-17 06:07:29.221 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:29.260 | DEBUG    | ALLSampler_Sentence:sample_next_round:339 - search for centroid: Strength
# 2024-05-17 06:07:29.427 | DEBUG    | ALLSampler_Sentence:sample_next_round:341 - FAISS index D shape (1, 46620), I shape: (1, 46620)
# 2024-05-17 06:07:29.467 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 06:07:29.467 | INFO     | ALLSampler_Sentence:sample_next_round:348 - AFTER FAISS INDEXING distance shape: (929928, 10)
# 2024-05-17 06:07:29.471 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:271 - Compute min difference between distances to any two centroids.
# 2024-05-17 06:07:31.049 | DEBUG    | ALLSampler_Sentence:sort_dist_diff:274 - min_dist diferences shape: (929928, 10, 10)
# 2024-05-17 06:07:32.342 | DEBUG    | ALLSampler_Sentence:sample_next_round:351 - The Sorted sentence IDs according to the distances: the sorted_sids length is: 37786
# 2024-05-17 06:07:32.444 | DEBUG    | ALLSampler_Sentence:sample_next_round:356 - AFTER EXCLUDE SAMPLED SENT ID: the sorted_sid_excludeSampled length is: 2
# 2024-05-17 06:07:32.461 | DEBUG    | ALLSampler_Sentence:sample_next_round:371 - new sampled unique sent num: 2
# 2024-05-17 06:07:32.462 | DEBUG    | ALLSampler_Sentence:sample_next_round:372 - new remaining unique sent num: 11968
# 2024-05-17 06:07:32.498 | DEBUG    | ALLSampler_Sentence:sample_next_round:377 - BEFORE update model with old sampled data 782906, old remaining data 150000
# 2024-05-17 06:07:32.500 | DEBUG    | ALLSampler_Sentence:sample_next_round:380 - new_sampled 38, new remaining data 149962
# 2024-05-17 06:07:32.556 | DEBUG    | ALLSampler_Sentence:sample_next_round:383 - AFTER update model with new sampled data 782944, new remaining data 149962
# 2024-05-17 06:07:32.733 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39830, remaining sentences: 11968
# 2024-05-17 06:07:32.733 | INFO     | ALLSampler_Sentence:keep_sample:85 - current sampled sentences: 39830, remaining sentences: 11968
# 2024-05-17 06:07:32.784 | INFO     | ALLSampler_Sentence:simulate_rounds:100 - It's the last round, now add all docs to sampled.
# 2024-05-17 06:07:32.784 | INFO     | ALLSampler_Sentence:simulate_rounds:100 - It's the last round, now add all docs to sampled.
# 2024-05-17 06:07:53.646 | DEBUG    | CRFWrapper_Sentence:fit:285 - Reset and train CRF model...
# 2024-05-17 06:18:01.520 | DEBUG    | CRFWrapper_Sentence:fit:293 - Training complete.
# 2024-05-17 06:18:02.463 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:353 - Predicting eval sents...
# 2024-05-17 06:18:28.158 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:357 - Calculate scores from bootstrapping 200 times
# 2024-05-17 06:22:43.810 | DEBUG    | CRFWrapper_Sentence:bootstrap_eval_DFsent:366 - complete
# 2024-05-17 06:22:43.908 | DEBUG    | ALLSampler_Sentence:simulate_rounds:106 - {'precision': 0.9458790131789627, 'recall': 0.8594719129205981, 'f1': 0.9006056047716083}

# %%
joblib.dump(all_scores, r'../data/n2c2/scores_sentence_sampling/ner_VBmin_scores_sentenceSampling_fixed.joblib')
# Out:
# ['../data/n2c2/scores_sentence_sampling/ner_VBmin_scores_sentenceSampling_fixed.joblib']
